# %% [markdown]
# # Financial AI Agent
# ***
# **An AI-powered conversational assistant that helps retail banking customers understand their financial behavior through natural language queries.**
# ***
#
# This project implements a production-grade Financial AI Agent that:
# * Understands natural language financial questions
# * Executes queries against transaction data with accurate calculations
# * Explains answers in simple, conversational language
# * Logs complete reasoning trails for compliance and observability
# ***
# ⚠️ Note on Data:
# * transactions.csv contains partial, synthetically generated data for demonstration purposes only. It is not real banking data. In production, this would connect to actual transaction databases.

# %%
# import project_structure as ps
# ps.show_project_structure()

# %%
# ============================================================================
# STANDARD LIBRARY IMPORTS
# ============================================================================

import os
import sys
import json
from pathlib import Path
from datetime import date, datetime, timedelta
from typing import Dict, Any, List, Optional
from pprint import pprint

# ============================================================================
# THIRD-PARTY IMPORTS
# ============================================================================

import pandas as pd
from dotenv import load_dotenv
from langchain_anthropic import ChatAnthropic
from langgraph.graph import StateGraph

# ============================================================================
# PROMPTS (LLM-1 & LLM-2)
# ============================================================================

from prompts.llm1_prompt import OPTIMIZED_ROUTER_SYSTEM_PROMPT
from prompts.llm2_prompt import llm2_prompt_builder, BASE_LLM2_SYSTEM_PROMPT

# print("✅ Prompts imported successfully")

# ============================================================================
# SCHEMAS & MODELS
# ============================================================================

from schemas.router_models import (
    GraphState,
    RouterOutput,
    ConversationSummary,
    PreferenceEntry,
    ExecutionResult,
    BackofficeLog,
    DataSources,
    ClarificationStep
)

from schemas.executor_models_llm2 import (
    TransactionQuerySpec,
    TransactionQueryResult,
    TransactionRecord,
)

# print("✅ Schemas & models imported successfully")

# ============================================================================
# GRAPH DEFINITION (LangGraph Nodes & Edges)
# ============================================================================

from graph_definition import (
    build_graph,
    router_node,
    vague_handler_node,
    executor_node,
    summary_update_node,
    build_router_payload,
    build_executor_payload
)

# print("✅ Graph definition imported successfully")

# ============================================================================
# TOOLS
# ============================================================================

from schemas.transactions_tool import (
    query_transactions_lc_tool, 
    query_transactions_tool
)

# print("✅ Tools imported successfully")

# ============================================================================
# BACK-OFFICE LOGGING
# ============================================================================

import backoffice_logging as bolog

# print("✅ Back-office logging imported successfully")

# ============================================================================
# TESTS
# ============================================================================

# import tests.llm1_tests as tst_llm1
# import tests.llm2_tests as tst_llm2
# import tests.pipeline_no_rag_tests as tst_no_rag_pipeline

# print("✅ Test modules imported successfully")

# %% [markdown]
# # Configurations

# %%
# Enable autoreload for development
# %load_ext autoreload
# %autoreload 2

# %%
"""
Create prompts/__init__.py
Makes prompts/ directory a proper Python package
"""

from pathlib import Path

# Define the complete content
INIT_CONTENT = """\"\"\"
Prompt modules for LLM-1 (Router & Clarifier) and LLM-2 (Executor)
\"\"\"

from .llm1_prompt import OPTIMIZED_ROUTER_SYSTEM_PROMPT
from .llm2_prompt import llm2_prompt_builder, BASE_LLM2_SYSTEM_PROMPT

__all__ = [
    'OPTIMIZED_ROUTER_SYSTEM_PROMPT',
    'llm2_prompt_builder',
    'BASE_LLM2_SYSTEM_PROMPT',
]
"""

# Create the file
project_root = Path.cwd()
init_file = project_root / "prompts" / "__init__.py"

print("=" * 80)
print("Creating prompts/__init__.py")
print("=" * 80)

# Write file
with open(init_file, 'w', encoding='utf-8') as f:
    f.write(INIT_CONTENT)

# # Verify
# if init_file.exists():
#     file_size = init_file.stat().st_size
#     print(f"\n✅ SUCCESS: File created")
#     print(f"   Location: {init_file}")
#     print(f"   Size: {file_size} bytes")
    
#     # Show contents
#     print("\n📄 File Contents:")
#     print("-" * 80)
#     with open(init_file, 'r', encoding='utf-8') as f:
#         print(f.read())
#     print("-" * 80)
    
#     print("\n" + "=" * 80)
#     print("✅ DONE! Now restart kernel and re-run imports")
#     print("=" * 80)
# else:
#     print("\n❌ ERROR: File was not created")
# Out:
# ================================================================================
# Creating prompts/__init__.py
# ================================================================================

# %%
# Load autoreload extension
# %load_ext autoreload

# Set autoreload mode
# Mode 2: Reload all modules (except those excluded) every time before executing code
# %autoreload 2
    
print("✅ Autoreload enabled (mode 2)")
print("   All modules will be automatically reloaded when changed")
print("\n📝 Watched modules:")
print("   • All modules in schemas/")
print("   • All modules in prompts/")
print("   • All modules in tests/")
print("   • Changes will be reflected immediately without kernel restart")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ✅ Autoreload enabled (mode 2)
#    All modules will be automatically reloaded when changed
#
# 📝 Watched modules:
#    • All modules in schemas/
#    • All modules in prompts/
#    • All modules in tests/
#    • Changes will be reflected immediately without kernel restart

# %% [markdown]
# # ***************************************************************************************

# %% [markdown]
# # TEST-1: Schema Validation for all Pydantic models
# ***
# * Validate all Pydantic models load correctly before running LLM or RAG tests.
# * No LLM calls, no API keys needed - runs in <1 second.
# ***
# **Schemas Tested:**
# * **PreferenceEntry** - User preferences with override tracking (previous_value, previous_turn_id)
# * **ConversationSummary** - Session-scoped preferences (time_window, amount_threshold_large)
# * **RouterOutput** - LLM-1 structured output (clarity, core_use_cases, summary_update)
# * **BackofficeLog** - Compliance logging with reasoning_steps and data_sources
# * **GraphState** - LangGraph state with raw_messages for multi-turn
# ***

# %%
import tests.test_schemas as ts
ts.test_all_schemas()
# Out:
# ================================================================================
# 🧪 SCHEMA VALIDATION TESTS
# ================================================================================
#
# ✅ PreferenceEntry
#    Fields: value, source, turn_id, original_query, previous_value, previous_turn_id
#
# ✅ ResolvedDates
#    Fields: start_date, end_date, interpretation
#
# ✅ ConversationSummary
#    Fields: time_window, amount_threshold_large, account_scope, category_preferences
#
# ✅ RouterOutput
#    Fields: clarity, core_use_cases, uc_operations, primary_use_case, ...
#    Fields: complexity_axes, needed_tools, clarifying_question, missing_info, ...
#    Fields: summary_update, resolved_dates, resolved_trn_categories, resolved_amount_threshold
#
# ✅ DataSources
#    Fields: tables_used, fields_accessed, filters_applied, aggregations_used
#
# ✅ ClarificationStep
#    Fields: question, user_answer, turn_id
#
# ✅ BackofficeLog
#    Fields: user_query, resolved_query, answer, analysis, reasoning_steps, ...
#    Fields: data_sources, transactions_analyzed, preferences_used, ...
#    Fields: clarification_history, confidence, rag_used, router_output_snapshot
#
# ✅ ExecutionResult
#    Fields: final_answer, backoffice_log
#
# ✅ GraphState
#    Fields: user_query, conversation_summary, router_output, execution_result, ...
#    Fields: messages_to_user, turn_id, session_id, raw_messages
#
# ================================================================================
# 📊 SCHEMA VALIDATION SUMMARY
# ================================================================================
#
# Total: 9 | Passed: 9 | Failed: 0
#
# ✅ ALL SCHEMAS VALID!
# ================================================================================
# [('PreferenceEntry', True, None),
#  ('ResolvedDates', True, None),
#  ('ConversationSummary', True, None),
#  ('RouterOutput', True, None),
#  ('DataSources', True, None),
#  ('ClarificationStep', True, None),
#  ('BackofficeLog', True, None),
#  ('ExecutionResult', True, None),
#  ('GraphState', True, None)]

# %% [markdown]
# # TEST-2: LLM-1 Multi-Turn (VAGUE Queries only)
# ***
# Test LLM-1 router_node and summary_update_node behavior with multi-turn flow.
# ***
# **What This Validates:**
# * **Turn 1 VAGUE** - Clarifying question generated for missing time_window or amount_threshold
# * **Turn 2 CLEAR** - Correct core_use_cases and primary_use_case after user answers
# * **summary_update** - LLM-1 produces preference updates from user clarification
# * **conversation_summary** - Preferences merged correctly via summary_update_node
# * **raw_messages** - Full conversation history passed to LLM-1 in Turn 2
# ***
# ***
# **LangGraph Coverage:**
# * ✅ router_node() execution
# * ✅ summary_update_node() execution
# * ✅ State passed correctly between nodes
# * ❌ Full graph.compile() - tested in pipeline tests
# * ❌ Conditional edges (VAGUE→vague_handler, CLEAR→executor) - tested in pipeline tests
# * ❌ app.invoke() end-to-end - tested in pipeline tests
# ***
# **Why Partial Coverage of LangGraph:**
# These tests isolate LLM-1 behavior by calling nodes directly.
# Full orchestration requires pipeline_tests.py which tests app.invoke() flow.
# ***

# %%
import tests.llm1_tests as tst_llm1

# # Test VAGUE queries 

# # 1: All queries (default)
vague_results = tst_llm1.llm1_test_all_vague_queries_multiturn()

# # 2: Random N queries
# vague_results = tst_llm1.llm1_test_all_vague_queries_multiturn(num_examples_to_check=2)
# clear_results = tst_llm1.llm1_test_all_clear_queries(num_examples_to_check=3)

# 3: Specific queries by ID
# vague_results = tst_llm1.llm1_test_all_vague_queries_multiturn(query_ids=[14, 15])
# Out:
# 📋 Testing all 5 VAGUE queries
# ====================================================================================================
# 🧪 LLM-1 MULTI-TURN TEST: VAGUE QUERIES
# ====================================================================================================
#
# Each conversation is INDEPENDENT with fresh ConversationSummary
# ====================================================================================================
#
# ====================================================================================================
# VAGUE Query #11: "What are my coffee shop expenses?"
# Missing: timeframe
# ====================================================================================================
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ TURN 1: User Query (VAGUE)                                                                       │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# 👤 User: "What are my coffee shop expenses?"
# 📝 ConversationSummary: (empty - fresh conversation)
#
# --- LLM-1 Router Iteration 1 ---
# C:\Users\USER\miniconda3\envs\p3.12_ml_env\Lib\site-packages\pydantic\v1\main.py:1054: UserWarning: LangSmith now uses UUID v7 for run and trace identifiers. This warning appears when passing custom IDs. Please use: from langsmith import uuid7
#             id = uuid7()
# Future versions will require UUID v7.
#   input_data = validator(cls_, input_data)
# LLM-1 wants to use 1 tool(s)
# Executing tool: search_transaction_categories with args: {'terms': ['coffee shop']}
#
# --- LLM-1 Router Iteration 2 ---
# LLM-1 responded without tool calls - parsing RouterOutput
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ TURN 1: LLM-1 Response (Clarification)                                                           │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# 🤖 LLM-1 Classification:
#    clarity: VAGUE
#    clarifying_question: For what time period would you like to know your coffee shop expenses? For example, last month, this year, or last 30 days?
#    missing_info: ['time_window']
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   TURN 1 VALIDATION
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    ✅ clarity: VAGUE
#    ✅ clarifying_question: present
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ TURN 2: User Clarification                                                                       │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# 👤 User: "Last month"
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ TURN 2: LLM-1 Final Response (CLEAR)                                                             │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# --- LLM-1 Router Iteration 1 ---
# LLM-1 wants to use 1 tool(s)
# Executing tool: search_transaction_categories with args: {'terms': ['coffee shop']}
#
# --- LLM-1 Router Iteration 2 ---
# LLM-1 responded without tool calls - parsing RouterOutput
#
# 🤖 LLM-1 Final Classification:
#    clarity: CLEAR
#    core_use_cases: ['UC-02', 'UC-03', 'UC-04']
#    primary_use_case: UC-02
#    complexity_axes: ['temporal', 'category']
#    needed_tools: ['query_transactions', 'search_transaction_categories']
#    summary_update: {'time_window': 'last_month'}
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   CONVERSATION SUMMARY UPDATE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#    📋 ConversationSummary:
#       • time_window: last_month
#       • amount_threshold_large: None
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   TURN 2 VALIDATION
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    ✅ clarity: CLEAR
#    ✅ core_use_cases: ['UC-02', 'UC-03', 'UC-04']
#    ✅ primary_use_case: UC-02
#    ✅ summary_update: generated
#    ✅ conversation_summary: correctly updated
#
# ✅ Query #11: PASSED
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   FULL LLM-1 OUTPUT (Turn 2)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# {
#   "clarity": "CLEAR",
#   "core_use_cases": [
#     "UC-02",
#     "UC-03",
#     "UC-04"
#   ],
#   "uc_operations": {
#     "UC-01": [],
#     "UC-02": [
#       "sum_spending_single_period_by_category"
#     ],
#     "UC-03": [
#       "temporal_interpretation"
#     ],
#     "UC-04": [
#       "category_mapping"
#     ],
#     "UC-05": []
#   },
#   "primary_use_case": "UC-02",
#   "complexity_axes": [
#     "temporal",
#     "category"
#   ],
#   "needed_tools": [
#     "query_transactions",
#     "search_transaction_categories"
#   ],
#   "clarifying_question": null,
#   "missing_info": [],
#   "summary_update": {
#     "time_window": "last_month"
#   },
#   "uc_confidence": "high",
#   "clarity_reason": "User clarified timeframe as 'last month' for the original coffee shop expenses query. This is a deterministic temporal reference (previous calendar month). Category 'coffee shop' is specific and maps to C806 Cafes & Coffee Shops subcategory.",
#   "router_notes": "Turn 2 clarification response. Original query was 'What are my coffee shop expenses?' which was VAGUE due to missing timeframe. User provided 'last month' which resolves the temporal ambiguity. Query is now CLEAR: aggregation (UC-02) of coffee shop spending (UC-04) for last month (UC-03). Selected C806 subcategory because 'coffee shop' is a specific merchant type, not a broad category.",
#   "resolved_dates": {
#     "start_date": "2025-11-01",
#     "end_date": "2025-11-30",
#     "interpretation": "last month from Dec 1, 2025 = November 2025 (Nov 1-30, 2025)"
#   },
#   "resolved_trn_categories": [
#     {
#       "user_term": "coffee shop",
#       "category_id": "C806",
#       "category_name": "Cafes & Coffee Shops",
#       "category_type": "subcategory",
#       "group_id": "CG800",
#       "group_name": "Dining",
#       "distance": 0.3590601086616516,
#       "confidence": "high"
#     }
#   ],
#   "resolved_amount_threshold": null
# }
#
# ====================================================================================================
# VAGUE Query #12: "Show me recent transactions"
# Missing: timeframe
# ====================================================================================================
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ TURN 1: User Query (VAGUE)                                                                       │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# 👤 User: "Show me recent transactions"
# 📝 ConversationSummary: (empty - fresh conversation)
#
# --- LLM-1 Router Iteration 1 ---
# LLM-1 responded without tool calls - parsing RouterOutput
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ TURN 1: LLM-1 Response (Clarification)                                                           │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# 🤖 LLM-1 Classification:
#    clarity: VAGUE
#    clarifying_question: What time period do you mean by 'recent'? For example: last 7 days, last 30 days, this month, or another timeframe?
#    missing_info: ['time_window']
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   TURN 1 VALIDATION
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    ✅ clarity: VAGUE
#    ✅ clarifying_question: present
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ TURN 2: User Clarification                                                                       │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# 👤 User: "Last 7 days"
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ TURN 2: LLM-1 Final Response (CLEAR)                                                             │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# --- LLM-1 Router Iteration 1 ---
# LLM-1 responded without tool calls - parsing RouterOutput
#
# 🤖 LLM-1 Final Classification:
#    clarity: CLEAR
#    core_use_cases: ['UC-03', 'UC-01']
#    primary_use_case: UC-03
#    complexity_axes: ['temporal']
#    needed_tools: ['query_transactions']
#    summary_update: {'time_window': 'last_7_days'}
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   CONVERSATION SUMMARY UPDATE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#    📋 ConversationSummary:
#       • time_window: last_7_days
#       • amount_threshold_large: None
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   TURN 2 VALIDATION
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    ✅ clarity: CLEAR
#    ✅ core_use_cases: ['UC-01', 'UC-03']
#    ✅ primary_use_case: UC-03
#    ✅ summary_update: generated
#    ✅ conversation_summary: correctly updated
#
# ✅ Query #12: PASSED
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   FULL LLM-1 OUTPUT (Turn 2)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# {
#   "clarity": "CLEAR",
#   "core_use_cases": [
#     "UC-03",
#     "UC-01"
#   ],
#   "uc_operations": {
#     "UC-01": [
#       "list_transactions"
#     ],
#     "UC-02": [],
#     "UC-03": [
#       "temporal_filter_last_7_days"
#     ],
#     "UC-04": [],
#     "UC-05": []
#   },
#   "primary_use_case": "UC-03",
#   "complexity_axes": [
#     "temporal"
#   ],
#   "needed_tools": [
#     "query_transactions"
#   ],
#   "clarifying_question": null,
#   "missing_info": [],
#   "summary_update": {
#     "time_window": "last_7_days"
#   },
#   "uc_confidence": "high",
#   "clarity_reason": "User clarified 'recent' means last 7 days, providing explicit temporal window",
#   "router_notes": "Turn 2 clarification response - user defined time_window preference as last_7_days for the original 'show me recent transactions' query",
#   "resolved_dates": {
#     "start_date": "2025-11-24",
#     "end_date": "2025-12-01",
#     "interpretation": "last 7 days from Dec 1, 2025 = Nov 24 - Dec 1, 2025"
#   },
#   "resolved_trn_categories": null,
#   "resolved_amount_threshold": null
# }
#
# ====================================================================================================
# VAGUE Query #13: "Show me large purchases"
# Missing: amount threshold
# ====================================================================================================
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ TURN 1: User Query (VAGUE)                                                                       │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# 👤 User: "Show me large purchases"
# 📝 ConversationSummary: (empty - fresh conversation)
#
# --- LLM-1 Router Iteration 1 ---
# LLM-1 responded without tool calls - parsing RouterOutput
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ TURN 1: LLM-1 Response (Clarification)                                                           │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# 🤖 LLM-1 Classification:
#    clarity: VAGUE
#    clarifying_question: What amount would you consider a 'large' purchase? For example, above $50, $100, or $500?
#    missing_info: ['amount_threshold_large']
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   TURN 1 VALIDATION
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    ✅ clarity: VAGUE
#    ✅ clarifying_question: present
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ TURN 2: User Clarification                                                                       │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# 👤 User: "Above $100"
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ TURN 2: LLM-1 Final Response (CLEAR)                                                             │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# --- LLM-1 Router Iteration 1 ---
# LLM-1 responded without tool calls - parsing RouterOutput
#
# 🤖 LLM-1 Final Classification:
#    clarity: CLEAR
#    core_use_cases: ['UC-01']
#    primary_use_case: UC-01
#    complexity_axes: []
#    needed_tools: ['query_transactions']
#    summary_update: {'amount_threshold_large': 100}
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   CONVERSATION SUMMARY UPDATE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#    📋 ConversationSummary:
#       • time_window: None
#       • amount_threshold_large: 100
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   TURN 2 VALIDATION
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    ✅ clarity: CLEAR
#    ✅ core_use_cases: ['UC-01']
#    ✅ primary_use_case: UC-01
#    ✅ summary_update: generated
#    ✅ conversation_summary: correctly updated
#
# ✅ Query #13: PASSED
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   FULL LLM-1 OUTPUT (Turn 2)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# {
#   "clarity": "CLEAR",
#   "core_use_cases": [
#     "UC-01"
#   ],
#   "uc_operations": {
#     "UC-01": [
#       "list_transactions_with_filter"
#     ],
#     "UC-02": [],
#     "UC-03": [],
#     "UC-04": [],
#     "UC-05": []
#   },
#   "primary_use_case": "UC-01",
#   "complexity_axes": [],
#   "needed_tools": [
#     "query_transactions"
#   ],
#   "clarifying_question": null,
#   "missing_info": [],
#   "summary_update": {
#     "amount_threshold_large": 100
#   },
#   "uc_confidence": "high",
#   "clarity_reason": "User clarified 'large' purchases as transactions above $100. Original query 'Show me large purchases' is now CLEAR with the amount threshold defined.",
#   "router_notes": "Turn 2 clarification response - user defined amount threshold preference. This is a direct retrieval query (UC-01) with amount filtering.",
#   "resolved_dates": null,
#   "resolved_trn_categories": null,
#   "resolved_amount_threshold": null
# }
#
# ====================================================================================================
# VAGUE Query #14: "Show me recent large purchases at coffee shops"
# Missing: timeframe + threshold
# ====================================================================================================
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ TURN 1: User Query (VAGUE)                                                                       │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# 👤 User: "Show me recent large purchases at coffee shops"
# 📝 ConversationSummary: (empty - fresh conversation)
#
# --- LLM-1 Router Iteration 1 ---
# LLM-1 wants to use 1 tool(s)
# Executing tool: search_transaction_categories with args: {'terms': ['coffee shops']}
#
# --- LLM-1 Router Iteration 2 ---
# LLM-1 responded without tool calls - parsing RouterOutput
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ TURN 1: LLM-1 Response (Clarification)                                                           │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# 🤖 LLM-1 Classification:
#    clarity: VAGUE
#    clarifying_question: To show your large purchases at coffee shops, I need two clarifications: (1) What timeframe do you mean by 'recent'? (Last 7 days, last 30 days, or this month?) (2) What amount would you consider a 'large' purchase? (Above $50, $100, or another amount?)
#    missing_info: ['time_window', 'amount_threshold_large']
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   TURN 1 VALIDATION
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    ✅ clarity: VAGUE
#    ✅ clarifying_question: present
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ TURN 2: User Clarification                                                                       │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# 👤 User: "Last 30 days, above $50"
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ TURN 2: LLM-1 Final Response (CLEAR)                                                             │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# --- LLM-1 Router Iteration 1 ---
# LLM-1 wants to use 1 tool(s)
# Executing tool: search_transaction_categories with args: {'terms': ['coffee shops']}
#
# --- LLM-1 Router Iteration 2 ---
# LLM-1 responded without tool calls - parsing RouterOutput
#
# 🤖 LLM-1 Final Classification:
#    clarity: CLEAR
#    core_use_cases: ['UC-01', 'UC-03', 'UC-04']
#    primary_use_case: UC-01
#    complexity_axes: ['temporal', 'category']
#    needed_tools: ['query_transactions']
#    summary_update: {'time_window': 'last_30_days', 'amount_threshold_large': 50, 'category_preferences': {'coffee_spending': 'cafes_only'}}
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   CONVERSATION SUMMARY UPDATE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#    📋 ConversationSummary:
#       • time_window: last_30_days
#       • amount_threshold_large: 50
#       • category_preferences: ['coffee_spending']
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   TURN 2 VALIDATION
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    ✅ clarity: CLEAR
#    ✅ core_use_cases: ['UC-01', 'UC-03', 'UC-04']
#    ✅ primary_use_case: UC-01
#    ✅ summary_update: generated
#    ✅ conversation_summary: correctly updated
#
# ✅ Query #14: PASSED
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   FULL LLM-1 OUTPUT (Turn 2)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# {
#   "clarity": "CLEAR",
#   "core_use_cases": [
#     "UC-01",
#     "UC-03",
#     "UC-04"
#   ],
#   "uc_operations": {
#     "UC-01": [
#       "list_transactions_with_multiple_filters"
#     ],
#     "UC-02": [],
#     "UC-03": [
#       "temporal_filter_last_30_days"
#     ],
#     "UC-04": [
#       "category_mapping"
#     ],
#     "UC-05": []
#   },
#   "primary_use_case": "UC-01",
#   "complexity_axes": [
#     "temporal",
#     "category"
#   ],
#   "needed_tools": [
#     "query_transactions"
#   ],
#   "clarifying_question": null,
#   "missing_info": [],
#   "summary_update": {
#     "time_window": "last_30_days",
#     "amount_threshold_large": 50,
#     "category_preferences": {
#       "coffee_spending": "cafes_only"
#     }
#   },
#   "uc_confidence": "high",
#   "clarity_reason": "User clarified 'recent' as last 30 days and 'large' as above $50. Original query now has complete information: time window (last 30 days), amount threshold ($50), and category (coffee shops = C806 Cafes & Coffee Shops).",
#   "router_notes": "Continuing from clarification - original VAGUE query (3 filters: time + amount + category) now CLEAR. Primary UC-01 because this is a multi-filter retrieval operation (time AND amount AND category). Category resolved to specific subcategory C806 (coffee shops is specific, not broad).",
#   "resolved_dates": {
#     "start_date": "2025-11-01",
#     "end_date": "2025-12-01",
#     "interpretation": "last 30 days from Dec 1, 2025 = Nov 1 - Dec 1, 2025"
#   },
#   "resolved_trn_categories": [
#     {
#       "user_term": "coffee shops",
#       "category_id": "C806",
#       "category_name": "Cafes & Coffee Shops",
#       "category_type": "subcategory",
#       "group_id": "CG800",
#       "group_name": "Dining",
#       "distance": 0.3171471953392029,
#       "confidence": "high"
#     }
#   ],
#   "resolved_amount_threshold": 50.0
# }
#
# ====================================================================================================
# VAGUE Query #15: "What are my pet expenses?"
# Missing: timeframe
# ====================================================================================================
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ TURN 1: User Query (VAGUE)                                                                       │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# 👤 User: "What are my pet expenses?"
# 📝 ConversationSummary: (empty - fresh conversation)
#
# --- LLM-1 Router Iteration 1 ---
# LLM-1 wants to use 1 tool(s)
# Executing tool: search_transaction_categories with args: {'terms': ['pet', 'pet expenses']}
#
# --- LLM-1 Router Iteration 2 ---
# LLM-1 responded without tool calls - parsing RouterOutput
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ TURN 1: LLM-1 Response (Clarification)                                                           │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# 🤖 LLM-1 Classification:
#    clarity: VAGUE
#    clarifying_question: For what time period would you like to know your pet expenses? For example, last month, this year, or last 30 days?
#    missing_info: ['time_window']
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   TURN 1 VALIDATION
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    ✅ clarity: VAGUE
#    ✅ clarifying_question: present
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ TURN 2: User Clarification                                                                       │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# 👤 User: "This year"
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ TURN 2: LLM-1 Final Response (CLEAR)                                                             │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# --- LLM-1 Router Iteration 1 ---
# LLM-1 wants to use 1 tool(s)
# Executing tool: search_transaction_categories with args: {'terms': ['pet', 'pet expenses']}
#
# --- LLM-1 Router Iteration 2 ---
# LLM-1 responded without tool calls - parsing RouterOutput
#
# 🤖 LLM-1 Final Classification:
#    clarity: CLEAR
#    core_use_cases: ['UC-02', 'UC-03', 'UC-04']
#    primary_use_case: UC-02
#    complexity_axes: ['temporal', 'category']
#    needed_tools: ['query_transactions', 'search_transaction_categories']
#    summary_update: {'time_window': 'this_year'}
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   CONVERSATION SUMMARY UPDATE
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#    📋 ConversationSummary:
#       • time_window: this_year
#       • amount_threshold_large: None
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   TURN 2 VALIDATION
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    ✅ clarity: CLEAR
#    ✅ core_use_cases: ['UC-02', 'UC-03', 'UC-04']
#    ✅ primary_use_case: UC-02
#    ✅ summary_update: generated
#    ✅ conversation_summary: correctly updated
#
# ✅ Query #15: PASSED
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   FULL LLM-1 OUTPUT (Turn 2)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# {
#   "clarity": "CLEAR",
#   "core_use_cases": [
#     "UC-02",
#     "UC-03",
#     "UC-04"
#   ],
#   "uc_operations": {
#     "UC-01": [],
#     "UC-02": [
#       "sum_spending_single_period_by_category"
#     ],
#     "UC-03": [
#       "temporal_interpretation"
#     ],
#     "UC-04": [
#       "category_mapping"
#     ],
#     "UC-05": []
#   },
#   "primary_use_case": "UC-02",
#   "complexity_axes": [
#     "temporal",
#     "category"
#   ],
#   "needed_tools": [
#     "query_transactions",
#     "search_transaction_categories"
#   ],
#   "clarifying_question": null,
#   "missing_info": [],
#   "summary_update": {
#     "time_window": "this_year"
#   },
#   "uc_confidence": "high",
#   "clarity_reason": "User clarified timeframe as 'this year' for the original pet expenses query. This is a clear aggregation query (how much spent) with deterministic temporal reference (this year = 2025-01-01 to 2025-12-31) and clear category mapping (pet expenses = CG1300 Pets group).",
#   "router_notes": "Continuing from clarification - original VAGUE query 'What are my pet expenses?' now CLEAR with timeframe 'this year'. Selected CG1300 (Pets group) because 'pet expenses' is a BROAD term covering all pet-related spending (veterinary, pet supplies, grooming, etc.).",
#   "resolved_dates": {
#     "start_date": "2025-01-01",
#     "end_date": "2025-12-31",
#     "interpretation": "this year = current calendar year 2025 (Jan 1 - Dec 31, 2025)"
#   },
#   "resolved_trn_categories": [
#     {
#       "user_term": "pet expenses",
#       "category_id": "CG1300",
#       "category_name": "Pets",
#       "category_type": "group",
#       "group_id": "CG1300",
#       "group_name": "Pets",
#       "distance": 0.23958836495876312,
#       "confidence": "high"
#     }
#   ],
#   "resolved_amount_threshold": null
# }
#
# ====================================================================================================
# 📊 FINAL TEST SUMMARY
# ====================================================================================================
#
# Total: 5 | Passed: 5 | Failed: 0
# Success Rate: 100.0%
#
# Results by Query:
#   ✅ #11: VAGUE → CLEAR | summary_update:✓ | conv_summary:✓
#   ✅ #12: VAGUE → CLEAR | summary_update:✓ | conv_summary:✓
#   ✅ #13: VAGUE → CLEAR | summary_update:✓ | conv_summary:✓
#   ✅ #14: VAGUE → CLEAR | summary_update:✓ | conv_summary:✓
#   ✅ #15: VAGUE → CLEAR | summary_update:✓ | conv_summary:✓
# ====================================================================================================

# %% [markdown]
# # *********************************** END TO END PIPELINE TESTS _WITH_ RAG *********************************
# # LLM-1+LLM-2 for Use-Cases 04 (must RAG usage):
# ---
#
# WHAT THE TEST SHOWS:
#
# 🔹 RAG TOOL EXECUTION:
#    - Was the tool called?
#    - What category was found?
#    - Expected vs Actual comparison
#
# 🔹 LLM-1 OUTPUT:
#    - Clarity correct?
#    - UC-04 detected?
#    - resolved_trn_categories populated?
#
# 🔹 LLM-2 INPUT CHECK:
#    - Did LLM-2 receive the category?
#    - Did LLM-2 receive the dates?
#
# 🔹 LLM-2 GROUNDING CHECK:
#    - Did LLM-2 use ONLY parameters from LLM-1?
#    - No hallucinated filters?
#
# 🔹 LLM-2 TOOL USAGE:
#    - Which tables accessed?
#    - What filters applied (SQL-like)?
#    - What aggregations used?
#
# 🔹 BACKOFFICE LOG:
#    - Complete audit trail
#    - Reasoning steps
#    - Data sources

# %%
from tests.pipeline_rag_tests import test_rag_pipeline

# # 1. Test ALL UC-04 queries (default):
# test_rag_pipeline()
test_rag_pipeline([3, 4, 7, 8, 9, 10, 16, 17])

# # 2. Test ALL queries in silent mode:
# test_rag_pipeline(silent=True)

# 3. Test specific queries (verbose - see all LLM iterations):
# test_rag_pipeline([3, 7, 10])

# # 4. Test with shorter wait time:
# test_rag_pipeline(wait_seconds=5)
# Out:
# ════════════════════════════════════════════════════════════════════════════════
# 🧪 RAG PIPELINE TEST - UC-04 QUERIES WITH CATEGORY RESOLUTION
# ════════════════════════════════════════════════════════════════════════════════
# 📋 Running 8 selected queries
#
# 📂 Loading Q&A mapping...
# ✅ Q&A mapping loaded
#
# 📊 Initializing dynamic expected calculator...
# ✅ Calculator ready (reference date: 2025-12-01)
#
# 📝 QUERIES TO TEST:
# ────────────────────────────────────────────────────────────────────────────────
#    [ 3] "How much did I spend on dining last month compared to September?"
#         → Expected: CG800
#    [ 4] "How much did I spend on groceries last month?"
#         → Expected: CG10000
#    [ 7] "How much did I spend on healthcare last month?"
#         → Expected: CG300
#    [ 8] "Show me my gym payments this year"
#         → Expected: C1701
#    [ 9] "How much did I spend on utilities in November compared to October?"
#         → Expected: CG200
#    [10] "Show me my last pharmacy transaction"
#         → Expected: C302
#    [16] "How much did I spend on dining in September 2024 compared to September 2025?"
#         → Expected: CG800
#    [17] "How much did I spend on groceries in November 2024?"
#         → Expected: CG10000
# ────────────────────────────────────────────────────────────────────────────────
#
# Configuration:
#    • Wait time: 10 seconds between queries
#    • Silent mode: OFF (see all LLM iterations)
#    • Reference date: 2025-12-01
#
# 🔧 Building graph...
# ✅ Graph compiled and ready
# ════════════════════════════════════════════════════════════════════════════════
#
#
# ════════════════════════════════════════════════════════════════════════════════
# 📝 QUERY 1/8 (ID: 3)
# ════════════════════════════════════════════════════════════════════════════════
# 👤 USER: "How much did I spend on dining last month compared to September?"
# 🎯 Expected Category: CG800 (Dining)
#
# --- LLM Execution Log ---
#
# --- LLM-1 Router Iteration 1 ---
# LLM-1 wants to use 1 tool(s)
# Executing tool: search_transaction_categories with args: {'terms': ['dining']}
#
# --- LLM-1 Router Iteration 2 ---
# LLM-1 responded without tool calls - parsing RouterOutput
#
# --- LLM-2 Iteration 1 ---
# LLM-2 wants to use 2 tools
# Executing tool: query_transactions with args: {'spec': {'user_id': 'USER_001', 'category_group_ids': ['CG800'], 'start_date': '2025-11-01', 'end_date': '2025-11-30', 'direction': 'D'}}
# Executing tool: query_transactions with args: {'spec': {'user_id': 'USER_001', 'category_group_ids': ['CG800'], 'start_date': '2025-09-01', 'end_date': '2025-09-30', 'direction': 'D'}}
#
# --- LLM-2 Iteration 2 ---
# LLM-2 responded without tool calls - expecting final JSON
# Attempting to parse JSON: {
#   "answer": "You spent $389.40 on dining in November (last month) compared to $668.20 in September. That's a decrease of $278.80, meaning you spent about 42% less on dining in November than you did ...
# ✅ Successfully wrapped LLM-2 output into ExecutionResult
#
# --- End Log ---
#
#
# 🔹 RAG TOOL EXECUTION:
# ────────────────────────────────────────────────────────────────────────────────
#    ✅ Tool Called: search_transaction_categories
#    ✅ Input: {'terms': ['dining']}
#
#    📊 RAG Results:
#    ┌──────────────┬────────────────────┬────────────┬──────────┬────────────┐
#    │ User Term    │ Category           │ ID         │ Distance │ Confidence │
#    ├──────────────┼────────────────────┼────────────┼──────────┼────────────┤
#    │ dining       │ Dining             │ CG800      │ 0.3647   │ high       │
#    └──────────────┴────────────────────┴────────────┴──────────┴────────────┘
#
#    🎯 Expected vs Actual:
#    ┌──────────────────────────────────────────────────────────────────────────┐
#    │ Expected: CG800 (Dining)                                                 │
#    │ Actual:   CG800 (Dining)                                                 │
#    │ Result:   ✅ MATCH                                                        │
#    └──────────────────────────────────────────────────────────────────────────┘
#
# 🔹 LLM-1 OUTPUT (Router):
# ────────────────────────────────────────────────────────────────────────────────
#    ✅ Clarity: CLEAR (expected: CLEAR)
#    ✅ UC-04 Detected: Yes
#       Core UCs: ['UC-03', 'UC-02', 'UC-04']
#       Expected: ['UC-03', 'UC-02', 'UC-04']
#    ✅ resolved_trn_categories: Populated (1 items)
#
#       Full content:
#       {
#         "user_term": "dining",
#         "category_id": "CG800",
#         "category_name": "Dining",
#         "category_type": "group",
#         "group_id": "CG800",
#         "group_name": "Dining",
#         "distance": 0.36473459005355835,
#         "confidence": "high"
# }
#
#    ✓ Resolved Dates:
#       • Start: 2025-11-01
#       • End: 2025-11-30
#       • Interpretation: last month = November 2025 (Nov 1-30); September = September 2025 (Sep 1-30)
#
#    ✓ Confidence: high
#
# 🔹 LLM-2 INPUT CHECK:
# ────────────────────────────────────────────────────────────────────────────────
#    ✅ Category ID passed to LLM-2: CG800
#       Expected: CG800
#    ✅ Dates passed to LLM-2: 2025-11-01 to 2025-11-30
#
#    ┌──────────────────────────────────────────────────────────────────────────┐
#    │ LLM-2 will receive:                                                      │
#    │   • category_id: CG800                                                   │
#    │   • category_name: Dining                                                │
#    │   • start_date: 2025-11-01                                               │
#    │   • end_date: 2025-11-30                                                 │
#    └──────────────────────────────────────────────────────────────────────────┘
#
# 🔹 LLM-2 GROUNDING CHECK:
# ────────────────────────────────────────────────────────────────────────────────
#    Verifying LLM-2 uses ONLY data from LLM-1 input...
#
#    │ category_id: CG800           │ ✅ GROUNDED           │
#    │ start_date:  2025-11-01      │ ✅ GROUNDED           │
#    │ end_date:    2025-11-30      │ ✅ GROUNDED           │
#
#    ✅ LLM-2 is GROUNDED: All parameters from LLM-1
#
# 🔹 LLM-2 TOOL USAGE:
# ────────────────────────────────────────────────────────────────────────────────
#    📁 Tables: ['transactions']
#    📋 Fields: ['transaction_id', 'user_id', 'account_id', 'amount', 'direction', 'date', 'month', 'year', 'categoryGroupId', 'categoryName', 'subCategoryId', 'subCategoryName']
#
#    🔍 Query Filters (SQL-like):
#    ┌──────────────────────────────────────────────────────────────────────────┐
#    │ Period 1 (November): user_id=USER_001, category_group_ids=['CG800'], sta │
#    │ Period 2 (September): user_id=USER_001, category_group_ids=['CG800'], st │
#    └──────────────────────────────────────────────────────────────────────────┘
#
#    📊 Aggregations: ['SUM(amount) for November period', 'SUM(amount) for September period', 'COUNT(transactions) for both periods', 'AVG(amount) for both periods', 'MAX(amount) for both periods', 'MIN(amount) for both periods', 'SUM(amount) grouped by subCategoryId for breakdown analysis']
#
# 🔹 FORMATTED ANSWER + DYNAMIC VALIDATION:
# ────────────────────────────────────────────────────────────────────────────────
#    💬 LLM-2 Answer:
#    ┌──────────────────────────────────────────────────────────────────────────┐
#    │ You spent $389.40 on dining in November (last month) compared to $668.20 │
#    └──────────────────────────────────────────────────────────────────────────┘
#
#    📊 Expected Values (calculated from transactions.csv):
#       • Period 1 (last_month): $389.40 (8 txns)
#       • Period 2 (september): $668.20 (20 txns)
#       • Difference: $-278.80 (-41.7%)
#
#    🔍 Validation:
#    ✅ Answer VALIDATED - amounts match expected values
#       ✅ Period 1 total $389.40 found
#       ✅ Period 2 total $668.20 found
#
# 🔹 BACKOFFICE LOG:
# ────────────────────────────────────────────────────────────────────────────────
#    {
#      "user_query": "I am USER_001. How much did I spend on dining last month com...",
#      "answer": "You spent $389.40 on dining in November (last month) compare...",
#      "analysis": {
#        "key_metrics": {"november_2025": {"total_spending": 389.4, "transaction_count": 8, "average_transaction": 48.68, "largest_transaction": 125.5, "smallest_transaction": 6.75, "breakdown_by_subcategory": {"Restaurants": 179.55, "Cafes & Coffee Shops": 140.1, "Food Delivery": 45.8, "Fast Food": 23.5}}, "september_2025": {"total_spending": 668.2, "transaction_count": 20, "average_transaction": 33.41, "largest_transaction": 92.4, "smallest_transaction": 4.95, "breakdown_by_subcategory": {"Restaurants": 328.0, "Food Delivery": 94.65, "Fast Food": 69.2, "Cafes & Coffee Shops": 38.55}}, "comparison": {"absolute_difference": -278.8, "percentage_change": -41.73, "transaction_count_difference": -12, "average_transaction_difference": 15.27, "trend": "November spending decreased significantly compared to September"}},
#      },
#      "reasoning_steps": [
#        "Step 1: Received query requesting comparison of dining spending b...",
#        "Step 2: Extracted pre-resolved parameters from router_output: cat...",
#        "Step 3: Identified CG800 as a category GROUP (starts with 'CG'), ...",
#        "Step 4: Called query_transactions for November 2025 with filters:...",
#        "Step 5: Received 8 transactions for November totaling $389.40",
#        ... (5 more steps)
#      ],
#      "data_sources": {
#        "tables_used": ["transactions"],
#        "fields_accessed": ["transaction_id", "user_id", "account_id", "amount", "direction", "date", "month", "year", "categoryGroupId", "categoryName", "subCategoryId", "subCategoryName"],
#        "filters_applied": ["Period 1 (November): user_id=USER_001, category_group_ids=['CG800'], start_date=2025-11-01, end_date=2025-11-30, direction=D (copied from router_output)", "Period 2 (September): user_id=USER_001, category_group_ids=['CG800'], start_date=2025-09-01, end_date=2025-09-30, direction=D (copied from router_output)"],
#        "aggregations_used": ["SUM(amount) for November period", "SUM(amount) for September period", "COUNT(transactions) for both periods", "AVG(amount) for both periods", "MAX(amount) for both periods", "MIN(amount) for both periods", "SUM(amount) grouped by subCategoryId for breakdown analysis"]
#      },
#      "transactions_analyzed": 28,
#      "confidence": "high",
#      "rag_used": false
#    }
# ════════════════════════════════════════════════════════════════════════════════
# 📋 QUERY 3 SUMMARY
# ════════════════════════════════════════════════════════════════════════════════
#    ✅ RAG tool called
#    ✅ RAG category correct
#    ✅ LLM-1 clarity correct
#    ✅ LLM-1 detected UC-04
#    ✅ LLM-1 resolved_trn_categories populated
#    ✅ LLM-2 received correct category
#    ✅ LLM-2 received dates
#    ✅ category_grounded
#    ✅ start_date_grounded
#    ✅ end_date_grounded
#    ✅ LLM-2 is GROUNDED
#    ✅ LLM-2 accessed tables
#    ✅ LLM-2 applied filters
#    ✅ aggregations_used
#    ✅ Answer matches expected values
#
#    RESULT: 15/15 checks passed
# ════════════════════════════════════════════════════════════════════════════════
#
# ⏳ Waiting 10 seconds...
#
#
# ════════════════════════════════════════════════════════════════════════════════
# 📝 QUERY 2/8 (ID: 4)
# ════════════════════════════════════════════════════════════════════════════════
# 👤 USER: "How much did I spend on groceries last month?"
# 🎯 Expected Category: CG10000 (Groceries)
#
# --- LLM Execution Log ---
#
# --- LLM-1 Router Iteration 1 ---
# LLM-1 wants to use 1 tool(s)
# Executing tool: search_transaction_categories with args: {'terms': ['groceries']}
#
# --- LLM-1 Router Iteration 2 ---
# LLM-1 responded without tool calls - parsing RouterOutput
#
# --- LLM-2 Iteration 1 ---
# LLM-2 wants to use 1 tools
# Executing tool: query_transactions with args: {'spec': {'user_id': 'USER_001', 'category_group_ids': ['CG10000'], 'start_date': '2025-11-01', 'end_date': '2025-11-30', 'direction': 'D'}}
#
# --- LLM-2 Iteration 2 ---
# LLM-2 responded without tool calls - expecting final JSON
# Attempting to parse JSON: {
#   "answer": "You spent $524.10 on groceries last month (November 2025). This was across 4 transactions, with an average of $131.03 per trip.",
#   "resolved_query": {
#     "original": "I am USER_001. H...
# ✅ Successfully wrapped LLM-2 output into ExecutionResult
#
# --- End Log ---
#
#
# 🔹 RAG TOOL EXECUTION:
# ────────────────────────────────────────────────────────────────────────────────
#    ✅ Tool Called: search_transaction_categories
#    ✅ Input: {'terms': ['groceries']}
#
#    📊 RAG Results:
#    ┌──────────────┬────────────────────┬────────────┬──────────┬────────────┐
#    │ User Term    │ Category           │ ID         │ Distance │ Confidence │
#    ├──────────────┼────────────────────┼────────────┼──────────┼────────────┤
#    │ groceries    │ Groceries          │ CG10000    │ 0.3404   │ high       │
#    └──────────────┴────────────────────┴────────────┴──────────┴────────────┘
#
#    🎯 Expected vs Actual:
#    ┌──────────────────────────────────────────────────────────────────────────┐
#    │ Expected: CG10000 (Groceries)                                            │
#    │ Actual:   CG10000 (Groceries)                                            │
#    │ Result:   ✅ MATCH                                                        │
#    └──────────────────────────────────────────────────────────────────────────┘
#
# 🔹 LLM-1 OUTPUT (Router):
# ────────────────────────────────────────────────────────────────────────────────
#    ✅ Clarity: CLEAR (expected: CLEAR)
#    ✅ UC-04 Detected: Yes
#       Core UCs: ['UC-03', 'UC-02', 'UC-04']
#       Expected: ['UC-03', 'UC-02', 'UC-04']
#    ✅ resolved_trn_categories: Populated (1 items)
#
#       Full content:
#       {
#         "user_term": "groceries",
#         "category_id": "CG10000",
#         "category_name": "Groceries",
#         "category_type": "group",
#         "group_id": "CG10000",
#         "group_name": "Groceries",
#         "distance": 0.34043729305267334,
#         "confidence": "high"
# }
#
#    ✓ Resolved Dates:
#       • Start: 2025-11-01
#       • End: 2025-11-30
#       • Interpretation: last month from Dec 1, 2025 = November 2025 (Nov 1-30, 2025)
#
#    ✓ Confidence: high
#
# 🔹 LLM-2 INPUT CHECK:
# ────────────────────────────────────────────────────────────────────────────────
#    ✅ Category ID passed to LLM-2: CG10000
#       Expected: CG10000
#    ✅ Dates passed to LLM-2: 2025-11-01 to 2025-11-30
#
#    ┌──────────────────────────────────────────────────────────────────────────┐
#    │ LLM-2 will receive:                                                      │
#    │   • category_id: CG10000                                                 │
#    │   • category_name: Groceries                                             │
#    │   • start_date: 2025-11-01                                               │
#    │   • end_date: 2025-11-30                                                 │
#    └──────────────────────────────────────────────────────────────────────────┘
#
# 🔹 LLM-2 GROUNDING CHECK:
# ────────────────────────────────────────────────────────────────────────────────
#    Verifying LLM-2 uses ONLY data from LLM-1 input...
#
#    │ category_id: CG10000         │ ✅ GROUNDED           │
#    │ start_date:  2025-11-01      │ ✅ GROUNDED           │
#    │ end_date:    2025-11-30      │ ✅ GROUNDED           │
#
#    ✅ LLM-2 is GROUNDED: All parameters from LLM-1
#
# 🔹 LLM-2 TOOL USAGE:
# ────────────────────────────────────────────────────────────────────────────────
#    📁 Tables: ['transactions']
#    📋 Fields: ['transaction_id', 'user_id', 'account_id', 'amount', 'direction', 'date', 'month', 'year', 'categoryGroupId', 'categoryName', 'subCategoryId', 'subCategoryName']
#
#    🔍 Query Filters (SQL-like):
#    ┌──────────────────────────────────────────────────────────────────────────┐
#    │ user_id = 'USER_001'                                                     │
#    │ category_group_ids = ['CG10000'] (Groceries group, copied from router_ou │
#    │ start_date = '2025-11-01' (copied from router_output.resolved_dates)     │
#    │ end_date = '2025-11-30' (copied from router_output.resolved_dates)       │
#    │ direction = 'D' (debit transactions only, representing spending)         │
#    └──────────────────────────────────────────────────────────────────────────┘
#
#    📊 Aggregations: ['SUM(amount) = 524.10', 'COUNT(transactions) = 4', 'AVG(amount) = 131.025', 'MAX(amount) = 167.30', 'MIN(amount) = 98.75']
#
# 🔹 FORMATTED ANSWER + DYNAMIC VALIDATION:
# ────────────────────────────────────────────────────────────────────────────────
#    💬 LLM-2 Answer:
#    ┌──────────────────────────────────────────────────────────────────────────┐
#    │ You spent $524.10 on groceries last month (November 2025). This was acro │
#    └──────────────────────────────────────────────────────────────────────────┘
#
#    📊 Expected Values (calculated from transactions.csv):
#       • Total: $524.10
#       • Count: 4 transactions
#       • Period: 2025-11-01 to 2025-11-30
#
#    🔍 Validation:
#    ✅ Answer VALIDATED - amounts match expected values
#       ✅ Total $524.10 found in answer
#
# 🔹 BACKOFFICE LOG:
# ────────────────────────────────────────────────────────────────────────────────
#    {
#      "user_query": "I am USER_001. How much did I spend on groceries last month?",
#      "answer": "You spent $524.10 on groceries last month (November 2025). T...",
#      "analysis": {
#        "key_metrics": {"total_spending": 524.1, "transaction_count": 4, "average_transaction": 131.025, "largest_transaction": 167.3, "smallest_transaction": 98.75, "spending_pattern": "Consistent weekly grocery shopping pattern with transactions on Nov 3, 8, 15, and 22", "primary_subcategory": "Supermarket (C10001) - all 4 transactions"},
#      },
#      "reasoning_steps": [
#        "Step 1: Received query and pre-resolved parameters from LLM-1 rou...",
#        "Step 2: Identified primary use case UC-02 (sum_spending_single_pe...",
#        "Step 3: Copied EXACT category_id='CG10000' from router_output.res...",
#        "Step 4: Copied EXACT dates start_date='2025-11-01', end_date='202...",
#        "Step 5: Built query_transactions call with category_group_ids=['C...",
#        ... (4 more steps)
#      ],
#      "data_sources": {
#        "tables_used": ["transactions"],
#        "fields_accessed": ["transaction_id", "user_id", "account_id", "amount", "direction", "date", "month", "year", "categoryGroupId", "categoryName", "subCategoryId", "subCategoryName"],
#        "filters_applied": ["user_id = 'USER_001'", "category_group_ids = ['CG10000'] (Groceries group, copied from router_output.resolved_trn_categories)", "start_date = '2025-11-01' (copied from router_output.resolved_dates)"]...,
#        "aggregations_used": ["SUM(amount) = 524.10", "COUNT(transactions) = 4", "AVG(amount) = 131.025", "MAX(amount) = 167.30", "MIN(amount) = 98.75"]
#      },
#      "transactions_analyzed": 4,
#      "confidence": "high",
#      "rag_used": false
#    }
# ════════════════════════════════════════════════════════════════════════════════
# 📋 QUERY 4 SUMMARY
# ════════════════════════════════════════════════════════════════════════════════
#    ✅ RAG tool called
#    ✅ RAG category correct
#    ✅ LLM-1 clarity correct
#    ✅ LLM-1 detected UC-04
#    ✅ LLM-1 resolved_trn_categories populated
#    ✅ LLM-2 received correct category
#    ✅ LLM-2 received dates
#    ✅ category_grounded
#    ✅ start_date_grounded
#    ✅ end_date_grounded
#    ✅ LLM-2 is GROUNDED
#    ✅ LLM-2 accessed tables
#    ✅ LLM-2 applied filters
#    ✅ aggregations_used
#    ✅ Answer matches expected values
#
#    RESULT: 15/15 checks passed
# ════════════════════════════════════════════════════════════════════════════════
#
# ⏳ Waiting 10 seconds...
#
#
# ════════════════════════════════════════════════════════════════════════════════
# 📝 QUERY 3/8 (ID: 7)
# ════════════════════════════════════════════════════════════════════════════════
# 👤 USER: "How much did I spend on healthcare last month?"
# 🎯 Expected Category: CG300 (Healthcare & Medical)
#
# --- LLM Execution Log ---
#
# --- LLM-1 Router Iteration 1 ---
# LLM-1 wants to use 1 tool(s)
# Executing tool: search_transaction_categories with args: {'terms': ['healthcare']}
#
# --- LLM-1 Router Iteration 2 ---
# LLM-1 responded without tool calls - parsing RouterOutput
#
# --- LLM-2 Iteration 1 ---
# LLM-2 wants to use 1 tools
# Executing tool: query_transactions with args: {'spec': {'user_id': 'USER_001', 'category_group_ids': ['CG300'], 'start_date': '2025-11-01', 'end_date': '2025-11-30', 'direction': 'D'}}
#
# --- LLM-2 Iteration 2 ---
# LLM-2 responded without tool calls - expecting final JSON
# Attempting to parse JSON: {
#   "answer": "You spent $136.75 on healthcare last month (November 2025). This included 3 transactions: a $75.50 doctor visit on November 5th, and two pharmacy purchases totaling $61.25 on November 1...
# ✅ Successfully wrapped LLM-2 output into ExecutionResult
#
# --- End Log ---
#
#
# 🔹 RAG TOOL EXECUTION:
# ────────────────────────────────────────────────────────────────────────────────
#    ✅ Tool Called: search_transaction_categories
#    ✅ Input: {'terms': ['healthcare']}
#
#    📊 RAG Results:
#    ┌──────────────┬────────────────────┬────────────┬──────────┬────────────┐
#    │ User Term    │ Category           │ ID         │ Distance │ Confidence │
#    ├──────────────┼────────────────────┼────────────┼──────────┼────────────┤
#    │ healthcare   │ Healthcare & Medic │ CG300      │ 0.3199   │ high       │
#    └──────────────┴────────────────────┴────────────┴──────────┴────────────┘
#
#    🎯 Expected vs Actual:
#    ┌──────────────────────────────────────────────────────────────────────────┐
#    │ Expected: CG300 (Healthcare & Medical)                                   │
#    │ Actual:   CG300 (Healthcare & Medical)                                   │
#    │ Result:   ✅ MATCH                                                        │
#    └──────────────────────────────────────────────────────────────────────────┘
#
# 🔹 LLM-1 OUTPUT (Router):
# ────────────────────────────────────────────────────────────────────────────────
#    ✅ Clarity: CLEAR (expected: CLEAR)
#    ✅ UC-04 Detected: Yes
#       Core UCs: ['UC-03', 'UC-02', 'UC-04']
#       Expected: ['UC-03', 'UC-02', 'UC-04']
#    ✅ resolved_trn_categories: Populated (1 items)
#
#       Full content:
#       {
#         "user_term": "healthcare",
#         "category_id": "CG300",
#         "category_name": "Healthcare & Medical",
#         "category_type": "group",
#         "group_id": "CG300",
#         "group_name": "Healthcare & Medical",
#         "distance": 0.3199106454849243,
#         "confidence": "high"
# }
#
#    ✓ Resolved Dates:
#       • Start: 2025-11-01
#       • End: 2025-11-30
#       • Interpretation: last month from Dec 1, 2025 = November 2025 (Nov 1-30, 2025)
#
#    ✓ Confidence: high
#
# 🔹 LLM-2 INPUT CHECK:
# ────────────────────────────────────────────────────────────────────────────────
#    ✅ Category ID passed to LLM-2: CG300
#       Expected: CG300
#    ✅ Dates passed to LLM-2: 2025-11-01 to 2025-11-30
#
#    ┌──────────────────────────────────────────────────────────────────────────┐
#    │ LLM-2 will receive:                                                      │
#    │   • category_id: CG300                                                   │
#    │   • category_name: Healthcare & Medical                                  │
#    │   • start_date: 2025-11-01                                               │
#    │   • end_date: 2025-11-30                                                 │
#    └──────────────────────────────────────────────────────────────────────────┘
#
# 🔹 LLM-2 GROUNDING CHECK:
# ────────────────────────────────────────────────────────────────────────────────
#    Verifying LLM-2 uses ONLY data from LLM-1 input...
#
#    │ category_id: CG300           │ ✅ GROUNDED           │
#    │ start_date:  2025-11-01      │ ✅ GROUNDED           │
#    │ end_date:    2025-11-30      │ ✅ GROUNDED           │
#
#    ✅ LLM-2 is GROUNDED: All parameters from LLM-1
#
# 🔹 LLM-2 TOOL USAGE:
# ────────────────────────────────────────────────────────────────────────────────
#    📁 Tables: ['transactions']
#    📋 Fields: ['transaction_id', 'user_id', 'account_id', 'amount', 'direction', 'date', 'categoryGroupId', 'subCategoryId', 'subCategoryName']
#
#    🔍 Query Filters (SQL-like):
#    ┌──────────────────────────────────────────────────────────────────────────┐
#    │ user_id = 'USER_001'                                                     │
#    │ category_group_ids = ['CG300'] (Healthcare & Medical group, copied from  │
#    │ start_date = '2025-11-01' (copied from router_output.resolved_dates)     │
#    │ end_date = '2025-11-30' (copied from router_output.resolved_dates)       │
#    │ direction = 'D' (debit transactions only for spending calculation)       │
#    └──────────────────────────────────────────────────────────────────────────┘
#
#    📊 Aggregations: ['SUM(amount) for total spending', 'COUNT(transactions) for transaction count', 'AVG(amount) for average transaction size', 'Subcategory breakdown aggregation']
#
# 🔹 FORMATTED ANSWER + DYNAMIC VALIDATION:
# ────────────────────────────────────────────────────────────────────────────────
#    💬 LLM-2 Answer:
#    ┌──────────────────────────────────────────────────────────────────────────┐
#    │ You spent $136.75 on healthcare last month (November 2025). This include │
#    └──────────────────────────────────────────────────────────────────────────┘
#
#    📊 Expected Values (calculated from transactions.csv):
#       • Total: $136.75
#       • Count: 3 transactions
#       • Period: 2025-11-01 to 2025-11-30
#
#    🔍 Validation:
#    ✅ Answer VALIDATED - amounts match expected values
#       ✅ Total $136.75 found in answer
#
# 🔹 BACKOFFICE LOG:
# ────────────────────────────────────────────────────────────────────────────────
#    {
#      "user_query": "I am USER_001. How much did I spend on healthcare last month...",
#      "answer": "You spent $136.75 on healthcare last month (November 2025). ...",
#      "analysis": {
#        "key_metrics": {"total_spending": 136.75, "transaction_count": 3, "average_transaction": 45.58, "largest_transaction": 75.5, "smallest_transaction": 28.75, "breakdown_by_subcategory": {"Doctor & Clinic (C301)": 75.5, "Pharmacy (C302)": 61.25}, "spending_pattern": "Healthcare spending concentrated in first half of month (doctor visit) with follow-up pharmacy purchases mid-to-late month"},
#      },
#      "reasoning_steps": [
#        "Step 1: Received query and pre-resolved parameters from LLM-1 rou...",
#        "Step 2: Extracted EXACT values from router_output: category_id=CG...",
#        "Step 3: Identified category_id 'CG300' starts with 'CG' prefix, t...",
#        "Step 4: Built query_transactions call with: user_id=USER_001, cat...",
#        "Step 5: Executed query_transactions tool and received 3 matching ...",
#        ... (3 more steps)
#      ],
#      "data_sources": {
#        "tables_used": ["transactions"],
#        "fields_accessed": ["transaction_id", "user_id", "account_id", "amount", "direction", "date", "categoryGroupId", "subCategoryId", "subCategoryName"],
#        "filters_applied": ["user_id = 'USER_001'", "category_group_ids = ['CG300'] (Healthcare & Medical group, copied from router_output.resolved_trn_categories)", "start_date = '2025-11-01' (copied from router_output.resolved_dates)"]...,
#        "aggregations_used": ["SUM(amount) for total spending", "COUNT(transactions) for transaction count", "AVG(amount) for average transaction size", "Subcategory breakdown aggregation"]
#      },
#      "transactions_analyzed": 3,
#      "confidence": "high",
#      "rag_used": false
#    }
# ════════════════════════════════════════════════════════════════════════════════
# 📋 QUERY 7 SUMMARY
# ════════════════════════════════════════════════════════════════════════════════
#    ✅ RAG tool called
#    ✅ RAG category correct
#    ✅ LLM-1 clarity correct
#    ✅ LLM-1 detected UC-04
#    ✅ LLM-1 resolved_trn_categories populated
#    ✅ LLM-2 received correct category
#    ✅ LLM-2 received dates
#    ✅ category_grounded
#    ✅ start_date_grounded
#    ✅ end_date_grounded
#    ✅ LLM-2 is GROUNDED
#    ✅ LLM-2 accessed tables
#    ✅ LLM-2 applied filters
#    ✅ aggregations_used
#    ✅ Answer matches expected values
#
#    RESULT: 15/15 checks passed
# ════════════════════════════════════════════════════════════════════════════════
#
# ⏳ Waiting 10 seconds...
#
#
# ════════════════════════════════════════════════════════════════════════════════
# 📝 QUERY 4/8 (ID: 8)
# ════════════════════════════════════════════════════════════════════════════════
# 👤 USER: "Show me my gym payments this year"
# 🎯 Expected Category: C1701 (Gym & Fitness Center)
#
# --- LLM Execution Log ---
#
# --- LLM-1 Router Iteration 1 ---
# LLM-1 wants to use 1 tool(s)
# Executing tool: search_transaction_categories with args: {'terms': ['gym']}
#
# --- LLM-1 Router Iteration 2 ---
# LLM-1 responded without tool calls - parsing RouterOutput
#
# --- LLM-2 Iteration 1 ---
# LLM-2 wants to use 1 tools
# Executing tool: query_transactions with args: {'spec': {'user_id': 'USER_001', 'sub_category_ids': ['C1701'], 'start_date': '2025-01-01', 'end_date': '2025-12-31', 'direction': 'D'}}
#
# --- LLM-2 Iteration 2 ---
# LLM-2 responded without tool calls - expecting final JSON
# Attempting to parse JSON: {
#   "answer": "You have 11 gym payments this year (2025), all from your checking account. Each payment is $49.99, charged on the 2nd of each month from January through November. Your total gym spendin...
# ✅ Successfully wrapped LLM-2 output into ExecutionResult
#
# --- End Log ---
#
#
# 🔹 RAG TOOL EXECUTION:
# ────────────────────────────────────────────────────────────────────────────────
#    ✅ Tool Called: search_transaction_categories
#    ✅ Input: {'terms': ['gym']}
#
#    📊 RAG Results:
#    ┌──────────────┬────────────────────┬────────────┬──────────┬────────────┐
#    │ User Term    │ Category           │ ID         │ Distance │ Confidence │
#    ├──────────────┼────────────────────┼────────────┼──────────┼────────────┤
#    │ gym          │ Gym & Fitness Cent │ C1701      │ 0.3940   │ high       │
#    └──────────────┴────────────────────┴────────────┴──────────┴────────────┘
#
#    🎯 Expected vs Actual:
#    ┌──────────────────────────────────────────────────────────────────────────┐
#    │ Expected: C1701 (Fitness & Sports)                                       │
#    │ Actual:   C1701 (Gym & Fitness Center)                                   │
#    │ Result:   ✅ MATCH                                                        │
#    └──────────────────────────────────────────────────────────────────────────┘
#
# 🔹 LLM-1 OUTPUT (Router):
# ────────────────────────────────────────────────────────────────────────────────
#    ✅ Clarity: CLEAR (expected: CLEAR)
#    ✅ UC-04 Detected: Yes
#       Core UCs: ['UC-03', 'UC-04']
#       Expected: ['UC-03', 'UC-01', 'UC-04']
#    ✅ resolved_trn_categories: Populated (1 items)
#
#       Full content:
#       {
#         "user_term": "gym",
#         "category_id": "C1701",
#         "category_name": "Gym & Fitness Center",
#         "category_type": "subcategory",
#         "group_id": "CG1700",
#         "group_name": "Fitness & Sports",
#         "distance": 0.39401161670684814,
#         "confidence": "high"
# }
#
#    ✓ Resolved Dates:
#       • Start: 2025-01-01
#       • End: 2025-12-31
#       • Interpretation: this year = current calendar year 2025 (Jan 1 - Dec 31, 2025)
#
#    ✓ Confidence: high
#
# 🔹 LLM-2 INPUT CHECK:
# ────────────────────────────────────────────────────────────────────────────────
#    ✅ Category ID passed to LLM-2: C1701
#       Expected: C1701
#    ✅ Dates passed to LLM-2: 2025-01-01 to 2025-12-31
#
#    ┌──────────────────────────────────────────────────────────────────────────┐
#    │ LLM-2 will receive:                                                      │
#    │   • category_id: C1701                                                   │
#    │   • category_name: Gym & Fitness Center                                  │
#    │   • start_date: 2025-01-01                                               │
#    │   • end_date: 2025-12-31                                                 │
#    └──────────────────────────────────────────────────────────────────────────┘
#
# 🔹 LLM-2 GROUNDING CHECK:
# ────────────────────────────────────────────────────────────────────────────────
#    Verifying LLM-2 uses ONLY data from LLM-1 input...
#
#    │ category_id: C1701           │ ✅ GROUNDED           │
#    │ start_date:  2025-01-01      │ ✅ GROUNDED           │
#    │ end_date:    2025-12-31      │ ✅ GROUNDED           │
#
#    ✅ LLM-2 is GROUNDED: All parameters from LLM-1
#
# 🔹 LLM-2 TOOL USAGE:
# ────────────────────────────────────────────────────────────────────────────────
#    📁 Tables: ['transactions']
#    📋 Fields: ['transaction_id', 'user_id', 'account_id', 'account_type', 'amount', 'direction', 'date', 'month', 'year', 'dayOfWeek', 'categoryGroupId', 'categoryName', 'subCategoryId', 'subCategoryName']
#
#    🔍 Query Filters (SQL-like):
#    ┌──────────────────────────────────────────────────────────────────────────┐
#    │ user_id = 'USER_001'                                                     │
#    │ sub_category_ids = ['C1701'] (Gym & Fitness Center subcategory, copied f │
#    │ start_date = '2025-01-01' (copied from router_output.resolved_dates)     │
#    │ end_date = '2025-12-31' (copied from router_output.resolved_dates)       │
#    │ direction = 'D' (debit transactions only)                                │
#    └──────────────────────────────────────────────────────────────────────────┘
#
#    📊 Aggregations: ['COUNT (total transactions)', 'SUM (total debit amount)', 'AVG (average amount)', 'MIN/MAX (amount range)']
#
# 🔹 FORMATTED ANSWER + DYNAMIC VALIDATION:
# ────────────────────────────────────────────────────────────────────────────────
#    💬 LLM-2 Answer:
#    ┌──────────────────────────────────────────────────────────────────────────┐
#    │ You have 11 gym payments this year (2025), all from your checking accoun │
#    └──────────────────────────────────────────────────────────────────────────┘
#
#    📊 Expected Values (calculated from transactions.csv):
#       • Count: 11 transactions
#       • Total: $549.89
#       • Period: 2025-01-01 to 2025-12-31
#
#    🔍 Validation:
#    ✅ Answer VALIDATED - amounts match expected values
#       ✅ Count 11 found in answer
#       ✅ Total $549.89 found in answer
#
# 🔹 BACKOFFICE LOG:
# ────────────────────────────────────────────────────────────────────────────────
#    {
#      "user_query": "I am USER_001. Show me my gym payments this year",
#      "answer": "You have 11 gym payments this year (2025), all from your che...",
#      "analysis": {
#        "key_metrics": "Total transactions: 11, Total amount: $549.89, Average payment: $49.99, Payment pattern: Monthly recurring on the 2nd of each month, Consistency: All payments are identical ($49.99), suggesting a fixed monthly gym membership. Coverage: January through November 2025 (11 months), December payment not yet recorded.",
#      },
#      "reasoning_steps": [
#        "Step 1: Received query and pre-resolved parameters from LLM-1",
#        "Step 2: Copied EXACT values: category_id=C1701 (subcategory, not ...",
#        "Step 3: Identified C1701 as subcategory (starts with 'C' but not ...",
#        "Step 4: Called query_transactions with filters: sub_category_ids=...",
#        "Step 5: Received 11 transactions from database",
#        ... (3 more steps)
#      ],
#      "data_sources": {
#        "tables_used": ["transactions"],
#        "fields_accessed": ["transaction_id", "user_id", "account_id", "account_type", "amount", "direction", "date", "month", "year", "dayOfWeek", "categoryGroupId", "categoryName", "subCategoryId", "subCategoryName"],
#        "filters_applied": ["user_id = 'USER_001'", "sub_category_ids = ['C1701'] (Gym & Fitness Center subcategory, copied from router_output.resolved_trn_categories)", "start_date = '2025-01-01' (copied from router_output.resolved_dates)"]...,
#        "aggregations_used": ["COUNT (total transactions)", "SUM (total debit amount)", "AVG (average amount)", "MIN/MAX (amount range)"]
#      },
#      "transactions_analyzed": 11,
#      "confidence": "high",
#      "rag_used": false
#    }
# ════════════════════════════════════════════════════════════════════════════════
# 📋 QUERY 8 SUMMARY
# ════════════════════════════════════════════════════════════════════════════════
#    ✅ RAG tool called
#    ✅ RAG category correct
#    ✅ LLM-1 clarity correct
#    ✅ LLM-1 detected UC-04
#    ✅ LLM-1 resolved_trn_categories populated
#    ✅ LLM-2 received correct category
#    ✅ LLM-2 received dates
#    ✅ category_grounded
#    ✅ start_date_grounded
#    ✅ end_date_grounded
#    ✅ LLM-2 is GROUNDED
#    ✅ LLM-2 accessed tables
#    ✅ LLM-2 applied filters
#    ✅ aggregations_used
#    ✅ Answer matches expected values
#
#    RESULT: 15/15 checks passed
# ════════════════════════════════════════════════════════════════════════════════
#
# ⏳ Waiting 10 seconds...
#
#
# ════════════════════════════════════════════════════════════════════════════════
# 📝 QUERY 5/8 (ID: 9)
# ════════════════════════════════════════════════════════════════════════════════
# 👤 USER: "How much did I spend on utilities in November compared to October?"
# 🎯 Expected Category: CG200 (Utilities & Bills)
#
# --- LLM Execution Log ---
#
# --- LLM-1 Router Iteration 1 ---
# LLM-1 wants to use 1 tool(s)
# Executing tool: search_transaction_categories with args: {'terms': ['utilities']}
#
# --- LLM-1 Router Iteration 2 ---
# LLM-1 responded without tool calls - parsing RouterOutput
#
# --- LLM-2 Iteration 1 ---
# LLM-2 wants to use 2 tools
# Executing tool: query_transactions with args: {'spec': {'user_id': 'USER_001', 'category_group_ids': ['CG200'], 'start_date': '2025-10-01', 'end_date': '2025-10-31', 'direction': 'D'}}
# Executing tool: query_transactions with args: {'spec': {'user_id': 'USER_001', 'category_group_ids': ['CG200'], 'start_date': '2025-11-01', 'end_date': '2025-11-30', 'direction': 'D'}}
#
# --- LLM-2 Iteration 2 ---
# LLM-2 responded without tool calls - expecting final JSON
# Attempting to parse JSON: {
#   "answer": "You spent $205.39 on utilities in October and $222.29 in November. That's an increase of $16.90 (about 8.2% more) in November compared to October. The increase was mainly due to higher ...
# ✅ Successfully wrapped LLM-2 output into ExecutionResult
#
# --- End Log ---
#
#
# 🔹 RAG TOOL EXECUTION:
# ────────────────────────────────────────────────────────────────────────────────
#    ✅ Tool Called: search_transaction_categories
#    ✅ Input: {'terms': ['utilities']}
#
#    📊 RAG Results:
#    ┌──────────────┬────────────────────┬────────────┬──────────┬────────────┐
#    │ User Term    │ Category           │ ID         │ Distance │ Confidence │
#    ├──────────────┼────────────────────┼────────────┼──────────┼────────────┤
#    │ utilities    │ Utilities & Bills  │ CG200      │ 0.3350   │ high       │
#    └──────────────┴────────────────────┴────────────┴──────────┴────────────┘
#
#    🎯 Expected vs Actual:
#    ┌──────────────────────────────────────────────────────────────────────────┐
#    │ Expected: CG200 (Utilities & Bills)                                      │
#    │ Actual:   CG200 (Utilities & Bills)                                      │
#    │ Result:   ✅ MATCH                                                        │
#    └──────────────────────────────────────────────────────────────────────────┘
#
# 🔹 LLM-1 OUTPUT (Router):
# ────────────────────────────────────────────────────────────────────────────────
#    ✅ Clarity: CLEAR (expected: CLEAR)
#    ✅ UC-04 Detected: Yes
#       Core UCs: ['UC-03', 'UC-02', 'UC-04']
#       Expected: ['UC-03', 'UC-02', 'UC-04']
#    ✅ resolved_trn_categories: Populated (1 items)
#
#       Full content:
#       {
#         "user_term": "utilities",
#         "category_id": "CG200",
#         "category_name": "Utilities & Bills",
#         "category_type": "group",
#         "group_id": null,
#         "group_name": null,
#         "distance": 0.335,
#         "confidence": "high"
# }
#
#    ✓ Resolved Dates:
#       • Start: 2025-10-01
#       • End: 2025-11-30
#       • Interpretation: November 2025 (Nov 1-30) compared to October 2025 (Oct 1-31)
#
#    ✓ Confidence: high
#
# 🔹 LLM-2 INPUT CHECK:
# ────────────────────────────────────────────────────────────────────────────────
#    ✅ Category ID passed to LLM-2: CG200
#       Expected: CG200
#    ✅ Dates passed to LLM-2: 2025-10-01 to 2025-11-30
#
#    ┌──────────────────────────────────────────────────────────────────────────┐
#    │ LLM-2 will receive:                                                      │
#    │   • category_id: CG200                                                   │
#    │   • category_name: Utilities & Bills                                     │
#    │   • start_date: 2025-10-01                                               │
#    │   • end_date: 2025-11-30                                                 │
#    └──────────────────────────────────────────────────────────────────────────┘
#
# 🔹 LLM-2 GROUNDING CHECK:
# ────────────────────────────────────────────────────────────────────────────────
#    Verifying LLM-2 uses ONLY data from LLM-1 input...
#
#    │ category_id: CG200           │ ✅ GROUNDED           │
#    │ start_date:  2025-10-01      │ ✅ GROUNDED           │
#    │ end_date:    2025-11-30      │ ✅ GROUNDED           │
#
#    ✅ LLM-2 is GROUNDED: All parameters from LLM-1
#
# 🔹 LLM-2 TOOL USAGE:
# ────────────────────────────────────────────────────────────────────────────────
#    📁 Tables: ['transactions']
#    📋 Fields: ['transaction_id', 'user_id', 'account_id', 'amount', 'direction', 'date', 'month', 'year', 'categoryGroupId', 'categoryName', 'subCategoryId', 'subCategoryName']
#
#    🔍 Query Filters (SQL-like):
#    ┌──────────────────────────────────────────────────────────────────────────┐
#    │ October query: user_id=USER_001, category_group_ids=['CG200'] (copied fr │
#    │ November query: user_id=USER_001, category_group_ids=['CG200'] (copied f │
#    └──────────────────────────────────────────────────────────────────────────┘
#
#    📊 Aggregations: ['SUM(amount) for October period', 'SUM(amount) for November period', 'Calculated difference and percentage change between periods', 'Grouped by subCategoryId for breakdown analysis']
#
# 🔹 FORMATTED ANSWER + DYNAMIC VALIDATION:
# ────────────────────────────────────────────────────────────────────────────────
#    💬 LLM-2 Answer:
#    ┌──────────────────────────────────────────────────────────────────────────┐
#    │ You spent $205.39 on utilities in October and $222.29 in November. That' │
#    └──────────────────────────────────────────────────────────────────────────┘
#
#    📊 Expected Values (calculated from transactions.csv):
#       • Period 1 (november_current_year): $222.29 (2 txns)
#       • Period 2 (october_current_year): $205.39 (2 txns)
#       • Difference: $16.90 (8.2%)
#
#    🔍 Validation:
#    ✅ Answer VALIDATED - amounts match expected values
#       ✅ Period 1 total $222.29 found
#       ✅ Period 2 total $205.39 found
#
# 🔹 BACKOFFICE LOG:
# ────────────────────────────────────────────────────────────────────────────────
#    {
#      "user_query": "I am USER_001. How much did I spend on utilities in November...",
#      "answer": "You spent $205.39 on utilities in October and $222.29 in Nov...",
#      "analysis": {
#        "key_metrics": {"october_spending": 205.39, "november_spending": 222.29, "absolute_difference": 16.9, "percentage_change": 8.23, "trend": "increase", "october_transactions": 2, "november_transactions": 2, "breakdown": {"electricity": {"october": 125.4, "november": 142.3, "change": 16.9}, "internet_cable": {"october": 79.99, "november": 79.99, "change": 0.0}}},
#      },
#      "reasoning_steps": [
#        "Step 1: Received query and pre-resolved parameters from LLM-1",
#        "Step 2: Identified primary UC-02 operation: sum_spending_multi_pe...",
#        "Step 3: Copied EXACT category_id='CG200' from router_output.resol...",
#        "Step 4: Verified category_id starts with 'CG' so used category_gr...",
#        "Step 5: Copied EXACT dates from router_output.resolved_dates: Oct...",
#        ... (7 more steps)
#      ],
#      "data_sources": {
#        "tables_used": ["transactions"],
#        "fields_accessed": ["transaction_id", "user_id", "account_id", "amount", "direction", "date", "month", "year", "categoryGroupId", "categoryName", "subCategoryId", "subCategoryName"],
#        "filters_applied": ["October query: user_id=USER_001, category_group_ids=['CG200'] (copied from router_output.resolved_trn_categories), start_date=2025-10-01, end_date=2025-10-31 (copied from router_output.resolved_dates), direction=D", "November query: user_id=USER_001, category_group_ids=['CG200'] (copied from router_output.resolved_trn_categories), start_date=2025-11-01, end_date=2025-11-30 (copied from router_output.resolved_dates), direction=D"],
#        "aggregations_used": ["SUM(amount) for October period", "SUM(amount) for November period", "Calculated difference and percentage change between periods", "Grouped by subCategoryId for breakdown analysis"]
#      },
#      "transactions_analyzed": 4,
#      "confidence": "high",
#      "rag_used": false
#    }
# ════════════════════════════════════════════════════════════════════════════════
# 📋 QUERY 9 SUMMARY
# ════════════════════════════════════════════════════════════════════════════════
#    ✅ RAG tool called
#    ✅ RAG category correct
#    ✅ LLM-1 clarity correct
#    ✅ LLM-1 detected UC-04
#    ✅ LLM-1 resolved_trn_categories populated
#    ✅ LLM-2 received correct category
#    ✅ LLM-2 received dates
#    ✅ category_grounded
#    ✅ start_date_grounded
#    ✅ end_date_grounded
#    ✅ LLM-2 is GROUNDED
#    ✅ LLM-2 accessed tables
#    ✅ LLM-2 applied filters
#    ✅ aggregations_used
#    ✅ Answer matches expected values
#
#    RESULT: 15/15 checks passed
# ════════════════════════════════════════════════════════════════════════════════
#
# ⏳ Waiting 10 seconds...
#
#
# ════════════════════════════════════════════════════════════════════════════════
# 📝 QUERY 6/8 (ID: 10)
# ════════════════════════════════════════════════════════════════════════════════
# 👤 USER: "Show me my last pharmacy transaction"
# 🎯 Expected Category: C302 (Pharmacy)
#
# --- LLM Execution Log ---
#
# --- LLM-1 Router Iteration 1 ---
# LLM-1 wants to use 1 tool(s)
# Executing tool: search_transaction_categories with args: {'terms': ['pharmacy']}
#
# --- LLM-1 Router Iteration 2 ---
# LLM-1 responded without tool calls - parsing RouterOutput
#
# --- LLM-2 Iteration 1 ---
# LLM-2 wants to use 1 tools
# Executing tool: query_transactions with args: {'spec': {'user_id': 'USER_001', 'sub_category_ids': ['C302'], 'sort_by': 'date_desc', 'limit': 1}}
#
# --- LLM-2 Iteration 2 ---
# LLM-2 responded without tool calls - expecting final JSON
# Attempting to parse JSON: {
#   "answer": "Your last pharmacy transaction was $28.75 on Tuesday, November 18, 2025 from your checking account.",
#   "resolved_query": {
#     "original": "I am USER_001. Show me my last pharmacy tran...
# ✅ Successfully wrapped LLM-2 output into ExecutionResult
#
# --- End Log ---
#
#
# 🔹 RAG TOOL EXECUTION:
# ────────────────────────────────────────────────────────────────────────────────
#    ✅ Tool Called: search_transaction_categories
#    ✅ Input: {'terms': ['pharmacy']}
#
#    📊 RAG Results:
#    ┌──────────────┬────────────────────┬────────────┬──────────┬────────────┐
#    │ User Term    │ Category           │ ID         │ Distance │ Confidence │
#    ├──────────────┼────────────────────┼────────────┼──────────┼────────────┤
#    │ pharmacy     │ Pharmacy           │ C302       │ 0.3050   │ high       │
#    └──────────────┴────────────────────┴────────────┴──────────┴────────────┘
#
#    🎯 Expected vs Actual:
#    ┌──────────────────────────────────────────────────────────────────────────┐
#    │ Expected: C302 (Healthcare & Medical)                                    │
#    │ Actual:   C302 (Pharmacy)                                                │
#    │ Result:   ✅ MATCH                                                        │
#    └──────────────────────────────────────────────────────────────────────────┘
#
# 🔹 LLM-1 OUTPUT (Router):
# ────────────────────────────────────────────────────────────────────────────────
#    ✅ Clarity: CLEAR (expected: CLEAR)
#    ✅ UC-04 Detected: Yes
#       Core UCs: ['UC-01', 'UC-04']
#       Expected: ['UC-01', 'UC-04']
#    ✅ resolved_trn_categories: Populated (1 items)
#
#       Full content:
#       {
#         "user_term": "pharmacy",
#         "category_id": "C302",
#         "category_name": "Pharmacy",
#         "category_type": "subcategory",
#         "group_id": "CG300",
#         "group_name": "Healthcare & Medical",
#         "distance": 0.30496466159820557,
#         "confidence": "high"
# }
#
#    ✓ Confidence: high
#
# 🔹 LLM-2 INPUT CHECK:
# ────────────────────────────────────────────────────────────────────────────────
#    ✅ Category ID passed to LLM-2: C302
# ...
#       • Difference: $142.85 (21.4%)
#
#    🔍 Validation:
#    ✅ Answer VALIDATED - amounts match expected values
#       ✅ Period 1 total $811.05 found
#       ✅ Period 2 total $668.20 found
#
# 🔹 BACKOFFICE LOG:
# ────────────────────────────────────────────────────────────────────────────────
#    {
#      "user_query": "I am USER_001. How much did I spend on dining in September 2...",
#      "answer": "In September 2024, you spent $811.05 on dining. In September...",
#      "analysis": {
#        "key_metrics": {"september_2024": {"total_spending": 811.05, "transaction_count": 2, "average_transaction": 405.53, "largest_transaction": 523.45, "smallest_transaction": 287.6}, "september_2025": {"total_spending": 668.2, "transaction_count": 20, "average_transaction": 33.41, "largest_transaction": 92.4, "smallest_transaction": 4.95}, "comparison": {"absolute_difference": -142.85, "percentage_change": -17.6, "transaction_count_change": 18, "spending_pattern": "September 2025 shows more frequent but smaller transactions compared to September 2024's fewer but larger transactions"}},
#      },
#      "reasoning_steps": [
#        "Step 1: Received query requesting comparison of dining spending b...",
#        "Step 2: Extracted pre-resolved parameters from router_output: cat...",
#        "Step 3: Identified category_id 'CG800' starts with 'CG', so used ...",
#        "Step 4: Called query_transactions for Period 1 with EXACT paramet...",
#        "Step 5: Received 2 transactions for September 2024 from database",
#        ... (6 more steps)
#      ],
#      "data_sources": {
#        "tables_used": ["transactions"],
#        "fields_accessed": ["transaction_id", "user_id", "account_id", "amount", "direction", "date", "categoryGroupId", "subCategoryId", "subCategoryName"],
#        "filters_applied": ["Period 1: user_id=USER_001, category_group_ids=['CG800'], start_date=2024-09-01, end_date=2024-09-30, direction=D (copied from router_output)", "Period 2: user_id=USER_001, category_group_ids=['CG800'], start_date=2025-09-01, end_date=2025-09-30, direction=D (copied from router_output)"],
#        "aggregations_used": ["SUM(amount) for September 2024", "SUM(amount) for September 2025", "COUNT(transactions) for both periods", "AVG(amount) for both periods", "Percentage change calculation"]
#      },
#      "transactions_analyzed": 22,
#      "confidence": "high",
#      "rag_used": false
#    }
# ════════════════════════════════════════════════════════════════════════════════
# 📋 QUERY 16 SUMMARY
# ════════════════════════════════════════════════════════════════════════════════
#    ✅ RAG tool called
#    ✅ RAG category correct
#    ✅ LLM-1 clarity correct
#    ✅ LLM-1 detected UC-04
#    ✅ LLM-1 resolved_trn_categories populated
#    ✅ LLM-2 received correct category
#    ✅ LLM-2 received dates
#    ✅ category_grounded
#    ✅ start_date_grounded
#    ✅ end_date_grounded
#    ✅ LLM-2 is GROUNDED
#    ✅ LLM-2 accessed tables
#    ✅ LLM-2 applied filters
#    ✅ aggregations_used
#    ✅ Answer matches expected values
#
#    RESULT: 15/15 checks passed
# ════════════════════════════════════════════════════════════════════════════════
#
# ⏳ Waiting 10 seconds...
#
#
# ════════════════════════════════════════════════════════════════════════════════
# 📝 QUERY 8/8 (ID: 17)
# ════════════════════════════════════════════════════════════════════════════════
# 👤 USER: "How much did I spend on groceries in November 2024?"
# 🎯 Expected Category: CG10000 (Groceries)
#
# --- LLM Execution Log ---
#
# --- LLM-1 Router Iteration 1 ---
# LLM-1 wants to use 1 tool(s)
# Executing tool: search_transaction_categories with args: {'terms': ['groceries']}
#
# --- LLM-1 Router Iteration 2 ---
# LLM-1 responded without tool calls - parsing RouterOutput
#
# --- LLM-2 Iteration 1 ---
# LLM-2 wants to use 1 tools
# Executing tool: query_transactions with args: {'spec': {'user_id': 'USER_001', 'category_group_ids': ['CG10000'], 'start_date': '2024-11-01', 'end_date': '2024-11-30', 'direction': 'D'}}
#
# --- LLM-2 Iteration 2 ---
# LLM-2 responded without tool calls - expecting final JSON
# Attempting to parse JSON: {
#   "answer": "You spent $412.75 on groceries in November 2024. This includes 2 transactions: $234.50 on November 10th and $178.25 on November 24th.",
#   "resolved_query": {
#     "original": "I am USER_...
# ✅ Successfully wrapped LLM-2 output into ExecutionResult
#
# --- End Log ---
#
#
# 🔹 RAG TOOL EXECUTION:
# ────────────────────────────────────────────────────────────────────────────────
#    ✅ Tool Called: search_transaction_categories
#    ✅ Input: {'terms': ['groceries']}
#
#    📊 RAG Results:
#    ┌──────────────┬────────────────────┬────────────┬──────────┬────────────┐
#    │ User Term    │ Category           │ ID         │ Distance │ Confidence │
#    ├──────────────┼────────────────────┼────────────┼──────────┼────────────┤
#    │ groceries    │ Groceries          │ CG10000    │ 0.3404   │ high       │
#    └──────────────┴────────────────────┴────────────┴──────────┴────────────┘
#
#    🎯 Expected vs Actual:
#    ┌──────────────────────────────────────────────────────────────────────────┐
#    │ Expected: CG10000 (Groceries)                                            │
#    │ Actual:   CG10000 (Groceries)                                            │
#    │ Result:   ✅ MATCH                                                        │
#    └──────────────────────────────────────────────────────────────────────────┘
#
# 🔹 LLM-1 OUTPUT (Router):
# ────────────────────────────────────────────────────────────────────────────────
#    ✅ Clarity: CLEAR (expected: CLEAR)
#    ✅ UC-04 Detected: Yes
#       Core UCs: ['UC-03', 'UC-02', 'UC-04']
#       Expected: ['UC-03', 'UC-02', 'UC-04']
#    ✅ resolved_trn_categories: Populated (1 items)
#
#       Full content:
#       {
#         "user_term": "groceries",
#         "category_id": "CG10000",
#         "category_name": "Groceries",
#         "category_type": "group",
#         "group_id": "CG10000",
#         "group_name": "Groceries",
#         "distance": 0.34043729305267334,
#         "confidence": "high"
# }
#
#    ✓ Resolved Dates:
#       • Start: 2024-11-01
#       • End: 2024-11-30
#       • Interpretation: November 2024 = full calendar month Nov 1-30, 2024
#
#    ✓ Confidence: high
#
# 🔹 LLM-2 INPUT CHECK:
# ────────────────────────────────────────────────────────────────────────────────
#    ✅ Category ID passed to LLM-2: CG10000
#       Expected: CG10000
#    ✅ Dates passed to LLM-2: 2024-11-01 to 2024-11-30
#
#    ┌──────────────────────────────────────────────────────────────────────────┐
#    │ LLM-2 will receive:                                                      │
#    │   • category_id: CG10000                                                 │
#    │   • category_name: Groceries                                             │
#    │   • start_date: 2024-11-01                                               │
#    │   • end_date: 2024-11-30                                                 │
#    └──────────────────────────────────────────────────────────────────────────┘
#
# 🔹 LLM-2 GROUNDING CHECK:
# ────────────────────────────────────────────────────────────────────────────────
#    Verifying LLM-2 uses ONLY data from LLM-1 input...
#
#    │ category_id: CG10000         │ ✅ GROUNDED           │
#    │ start_date:  2024-11-01      │ ✅ GROUNDED           │
#    │ end_date:    2024-11-30      │ ✅ GROUNDED           │
#
#    ✅ LLM-2 is GROUNDED: All parameters from LLM-1
#
# 🔹 LLM-2 TOOL USAGE:
# ────────────────────────────────────────────────────────────────────────────────
#    📁 Tables: ['transactions']
#    📋 Fields: ['transaction_id', 'user_id', 'account_id', 'amount', 'direction', 'date', 'month', 'year', 'dayOfWeek', 'categoryGroupId', 'categoryName', 'subCategoryId', 'subCategoryName']
#
#    🔍 Query Filters (SQL-like):
#    ┌──────────────────────────────────────────────────────────────────────────┐
#    │ user_id = 'USER_001'                                                     │
#    │ category_group_ids = ['CG10000'] (copied from router_output.resolved_trn │
#    │ start_date = '2024-11-01' (copied from router_output.resolved_dates.star │
#    │ end_date = '2024-11-30' (copied from router_output.resolved_dates.end_da │
#    │ direction = 'D' (debit transactions only, representing spending)         │
#    └──────────────────────────────────────────────────────────────────────────┘
#
#    📊 Aggregations: ['SUM(amount) for total spending = $412.75', 'COUNT(transactions) = 2', 'AVG(amount) = $206.38', 'MAX(amount) = $234.50', 'MIN(amount) = $178.25']
#
# 🔹 FORMATTED ANSWER + DYNAMIC VALIDATION:
# ────────────────────────────────────────────────────────────────────────────────
#    💬 LLM-2 Answer:
#    ┌──────────────────────────────────────────────────────────────────────────┐
#    │ You spent $412.75 on groceries in November 2024. This includes 2 transac │
#    └──────────────────────────────────────────────────────────────────────────┘
#
#    📊 Expected Values (calculated from transactions.csv):
#       • Total: $412.75
#       • Count: 2 transactions
#       • Period: 2024-11-01 to 2024-11-30
#
#    🔍 Validation:
#    ✅ Answer VALIDATED - amounts match expected values
#       ✅ Total $412.75 found in answer
#
# 🔹 BACKOFFICE LOG:
# ────────────────────────────────────────────────────────────────────────────────
#    {
#      "user_query": "I am USER_001. How much did I spend on groceries in November...",
#      "answer": "You spent $412.75 on groceries in November 2024. This includ...",
#      "analysis": {
#        "key_metrics": {"total_spending": 412.75, "transaction_count": 2, "average_transaction": 206.38, "largest_transaction": 234.5, "smallest_transaction": 178.25, "spending_pattern": "Two grocery shopping trips in November, both on Sundays (Nov 10 and Nov 24), with consistent spending amounts around $200 per trip"},
#      },
#      "reasoning_steps": [
#        "Step 1: Received query and pre-resolved parameters from LLM-1 (ro...",
#        "Step 2: Identified primary use case UC-02 (sum_spending_single_pe...",
#        "Step 3: Copied EXACT category_id='CG10000' from router_output.res...",
#        "Step 4: Copied EXACT dates: start_date='2024-11-01', end_date='20...",
#        "Step 5: Built query_transactions call with category_group_ids=['C...",
#        ... (4 more steps)
#      ],
#      "data_sources": {
#        "tables_used": ["transactions"],
#        "fields_accessed": ["transaction_id", "user_id", "account_id", "amount", "direction", "date", "month", "year", "dayOfWeek", "categoryGroupId", "categoryName", "subCategoryId", "subCategoryName"],
#        "filters_applied": ["user_id = 'USER_001'", "category_group_ids = ['CG10000'] (copied from router_output.resolved_trn_categories[0].category_id)", "start_date = '2024-11-01' (copied from router_output.resolved_dates.start_date)"]...,
#        "aggregations_used": ["SUM(amount) for total spending = $412.75", "COUNT(transactions) = 2", "AVG(amount) = $206.38", "MAX(amount) = $234.50", "MIN(amount) = $178.25"]
#      },
#      "transactions_analyzed": 2,
#      "confidence": "high",
#      "rag_used": false
#    }
# ════════════════════════════════════════════════════════════════════════════════
# 📋 QUERY 17 SUMMARY
# ════════════════════════════════════════════════════════════════════════════════
#    ✅ RAG tool called
#    ✅ RAG category correct
#    ✅ LLM-1 clarity correct
#    ✅ LLM-1 detected UC-04
#    ✅ LLM-1 resolved_trn_categories populated
#    ✅ LLM-2 received correct category
#    ✅ LLM-2 received dates
#    ✅ category_grounded
#    ✅ start_date_grounded
#    ✅ end_date_grounded
#    ✅ LLM-2 is GROUNDED
#    ✅ LLM-2 accessed tables
#    ✅ LLM-2 applied filters
#    ✅ aggregations_used
#    ✅ Answer matches expected values
#
#    RESULT: 15/15 checks passed
# ════════════════════════════════════════════════════════════════════════════════
#
#
# ════════════════════════════════════════════════════════════════════════════════
# 📊 FINAL TEST SUMMARY
# ════════════════════════════════════════════════════════════════════════════════
# Total Queries: 8
# Fully Passed:  8
# Partial/Failed: 0
# Success Rate:  100.0%
#
#    ✅ PASS - Query #3
#    ✅ PASS - Query #4
#    ✅ PASS - Query #7
#    ✅ PASS - Query #8
#    ✅ PASS - Query #9
#    ✅ PASS - Query #10
#    ✅ PASS - Query #16
#    ✅ PASS - Query #17
# ════════════════════════════════════════════════════════════════════════════════
# [{'id': 3,
#   'status': '✅ PASS',
#   'passed': True,
#   'checks': {'rag_called': True,
#    'category_match': True,
#    'clarity_correct': True,
#    'uc04_detected': True,
#    'categories_populated': True,
#    'correct_category_passed': True,
#    'dates_passed': True,
#    'category_grounded': True,
#    'start_date_grounded': True,
#    'end_date_grounded': True,
#    'fully_grounded': True,
#    'tables_accessed': True,
#    'filters_applied': True,
#    'aggregations_used': True,
#    'answer_validated': True}},
#  {'id': 4,
#   'status': '✅ PASS',
#   'passed': True,
#   'checks': {'rag_called': True,
#    'category_match': True,
#    'clarity_correct': True,
#    'uc04_detected': True,
#    'categories_populated': True,
#    'correct_category_passed': True,
#    'dates_passed': True,
#    'category_grounded': True,
#    'start_date_grounded': True,
#    'end_date_grounded': True,
#    'fully_grounded': True,
#    'tables_accessed': True,
#    'filters_applied': True,
#    'aggregations_used': True,
#    'answer_validated': True}},
#  {'id': 7,
#   'status': '✅ PASS',
#   'passed': True,
#   'checks': {'rag_called': True,
#    'category_match': True,
#    'clarity_correct': True,
#    'uc04_detected': True,
#    'categories_populated': True,
#    'correct_category_passed': True,
#    'dates_passed': True,
#    'category_grounded': True,
#    'start_date_grounded': True,
#    'end_date_grounded': True,
#    'fully_grounded': True,
#    'tables_accessed': True,
#    'filters_applied': True,
#    'aggregations_used': True,
#    'answer_validated': True}},
#  {'id': 8,
#   'status': '✅ PASS',
#   'passed': True,
#   'checks': {'rag_called': True,
#    'category_match': True,
#    'clarity_correct': True,
#    'uc04_detected': True,
#    'categories_populated': True,
#    'correct_category_passed': True,
#    'dates_passed': True,
#    'category_grounded': True,
#    'start_date_grounded': True,
#    'end_date_grounded': True,
#    'fully_grounded': True,
#    'tables_accessed': True,
#    'filters_applied': True,
#    'aggregations_used': True,
#    'answer_validated': True}},
#  {'id': 9,
#   'status': '✅ PASS',
#   'passed': True,
#   'checks': {'rag_called': True,
#    'category_match': True,
#    'clarity_correct': True,
#    'uc04_detected': True,
#    'categories_populated': True,
#    'correct_category_passed': True,
#    'dates_passed': True,
#    'category_grounded': True,
#    'start_date_grounded': True,
#    'end_date_grounded': True,
#    'fully_grounded': True,
#    'tables_accessed': True,
#    'filters_applied': True,
#    'aggregations_used': True,
#    'answer_validated': True}},
#  {'id': 10,
#   'status': '✅ PASS',
#   'passed': True,
#   'checks': {'rag_called': True,
#    'category_match': True,
#    'clarity_correct': True,
#    'uc04_detected': True,
#    'categories_populated': True,
#    'correct_category_passed': True,
#    'dates_passed': True,
#    'category_grounded': True,
#    'fully_grounded': True,
#    'tables_accessed': True,
#    'filters_applied': True,
#    'aggregations_used': True,
#    'answer_validated': True}},
#  {'id': 16,
#   'status': '✅ PASS',
#   'passed': True,
#   'checks': {'rag_called': True,
#    'category_match': True,
#    'clarity_correct': True,
#    'uc04_detected': True,
#    'categories_populated': True,
#    'correct_category_passed': True,
#    'dates_passed': True,
#    'category_grounded': True,
#    'start_date_grounded': True,
#    'end_date_grounded': True,
#    'fully_grounded': True,
#    'tables_accessed': True,
#    'filters_applied': True,
#    'aggregations_used': True,
#    'answer_validated': True}},
#  {'id': 17,
#   'status': '✅ PASS',
#   'passed': True,
#   'checks': {'rag_called': True,
#    'category_match': True,
#    'clarity_correct': True,
#    'uc04_detected': True,
#    'categories_populated': True,
#    'correct_category_passed': True,
#    'dates_passed': True,
#    'category_grounded': True,
#    'start_date_grounded': True,
#    'end_date_grounded': True,
#    'fully_grounded': True,
#    'tables_accessed': True,
#    'filters_applied': True,
#    'aggregations_used': True,
#    'answer_validated': True}}]

# %% [markdown]
# # **************************** END TO END PIPELINE TESTS _WITHOUT_ RAG *************************
# # Full pipeline tests WITHOUT RAG (for UC01, UC02, UC03): LLM-1+LLM-2
# ***
#
# **Silent Mode (silent=True (Default) => CLEAN OUTPUT)**
#
# ***
#
# * Usage:
#     * ✅ Normal testing - you just want to see results
#     * ✅ Multiple queries - clean output is easier to read
#     * ✅ Production-like testing - focus on LLM outputs
#
# * Functions:
#     * Test CLEAR queries (no category RAG needed)
#         * test_clear_queries_no_rag_trn_categories([1, 2],  wait_seconds=10)
#         * All queries: [1, 2, 5, 6]
#
#     * Test VAGUE queries (no category RAG needed)
#         * pipeline_tests import test_vague_queries_no_rag_trn_categories()
#         * All queries: [12, 13]
# ***
#
# **Verbose mode (silent=False => see all tool calls)**
#
# ***
#
# * Usage:
#     * 🐛 Debugging - something is failing and you need to see why
#     * 🔍 Learning - you want to understand what happens internally
#     * 🛠️ Development - testing new tools or graph nodes
# * Function:
#     * test_clear_queries_no_rag_trn_categories([12], wait_seconds=10)

# %%
from tests.pipeline_no_rag_tests import test_clear_queries_no_rag_trn_categories  # Test CLEAR queries (no category RAG needed)
from tests.pipeline_no_rag_tests import test_vague_queries_no_rag_trn_categories  # Test VAGUE queries (no category RAG needed)

# %% [markdown]
# ### Silent Mode ("clean output")

# %%
# # Silent Mode: CLEAR non-category queries, test 2 queries:
test_clear_queries_no_rag_trn_categories([1, 2], wait_seconds=10)
# Out:
# ====================================================================================================
#
# 🧪 TEST: CLEAR QUERIES WITHOUT RAG TRANSACTION CATEGORIES
#
# ====================================================================================================
#
# Testing 2 queries: [1, 2]
# Wait time: 10 seconds between queries
# Silent mode: ON
#
# 📂 Loading Q&A mapping...
# ✅ Q&A mapping loaded
# 🔧 Building graph...
# ✅ Graph compiled and ready
#
# ====================================================================================================
#
#
# ----------------------------------------------------------------------------------------------------
#
# 📝 QUERY 1/2 (ID: 1)
#
# ----------------------------------------------------------------------------------------------------
#
# 👤 USER: "What is my current balance?"
#
# 🔹 LLM-1 ROUTER OUTPUT:
#    ✓ Clarity: CLEAR
#    ✓ Core UCs: ['UC-01']
#    ✓ Primary UC: UC-01
#    ✓ UC Operations:
#       • UC-01: ['get_account_balance']
#    ✓ Complexity Axes: []
#    ✓ Resolved Dates: None (not temporal)
#    ✓ Resolved Categories: None (no categories)
#    ✓ Needed Tools: []
#    ✓ Confidence: high
#    ✓ Clarity Reason: Query requests a single direct value (current account balance) with no ambiguity. 'Current' is deterministic (means now/latest). This is a straightforward UC-01 direct lookup operation.
#
# 🔹 LLM-2 EXECUTOR OUTPUT:
#    ✓ Customer Answer:
#       "Your current account balance is $48,710.40. This represents your net position after all income and expenses through December 18, 2025."
#
#    📊 Analysis (Key Metrics):
#       • key_metrics: Total income (credits): $58,500.00 | Total expenses (debits): $9,789.60 | Net balance: $48,710.40 | Transaction count: 147 | Average transaction amount: $464.56
#
#    🔍 Reasoning Steps (7 steps):
#       1. Step 1: Received query requesting current account balance for USER_001
#       2. Step 2: Identified this as UC-01 direct data retrieval (get_account_balance subtype)
#       3. Step 3: No pre-resolved parameters provided by LLM-1 (resolved_dates=null, resolved_trn_categories=null, resolved_amount_threshold=null)
#       4. Step 4: Called query_transactions with user_id=USER_001 and no additional filters to retrieve all transactions
#       5. Step 5: Received 147 transactions from database spanning January 2024 to December 2025
#       6. Step 6: Calculated current balance from query result: total_credit_amount ($58,500.00) - total_debit_amount ($9,789.60) = net_amount ($48,710.40)
#       7. Step 7: Formatted answer showing current balance as $48,710.40
#
#    🗄️  Data Sources:
#       • Tables: ['transactions']
#       • Fields: ['user_id', 'amount', 'direction', 'date', 'account_id', 'account_type', 'transaction_id']
#       • Filters:
#          - user_id = USER_001
#       • Aggregations: ['SUM(credits) = $58,500.00', 'SUM(debits) = $9,789.60', 'NET = credits - debits = $48,710.40', 'COUNT(transactions) = 147']
#
#    📈 Transactions Analyzed: 147
#
#    🎯 Confidence: high
#
# ✅ PASS - Query 1
#
# ⏳ Waiting 10 seconds...
#
# ----------------------------------------------------------------------------------------------------
#
# 📝 QUERY 2/2 (ID: 2)
#
# ----------------------------------------------------------------------------------------------------
#
# 👤 USER: "Show me my last transaction"
#
# 🔹 LLM-1 ROUTER OUTPUT:
#    ✓ Clarity: CLEAR
#    ✓ Core UCs: ['UC-01']
#    ✓ Primary UC: UC-01
#    ✓ UC Operations:
#       • UC-01: ['retrieve_single_most_recent_transaction']
#    ✓ Complexity Axes: []
#    ✓ Resolved Dates: None (not temporal)
#    ✓ Resolved Categories: None (no categories)
#    ✓ Needed Tools: ['query_transactions']
#    ✓ Confidence: high
#    ✓ Clarity Reason: Query requests a single, most recent transaction - this is a direct retrieval operation with no ambiguity. 'Last transaction' has a deterministic meaning (most recent by date).
#
# 🔹 LLM-2 EXECUTOR OUTPUT:
#    ✓ Customer Answer:
#       "Your last transaction was $267.90 spent on Online Shopping on Thursday, December 18, 2025."
#
#    📊 Analysis (Key Metrics):
#       • key_metrics: Most recent transaction: $267.90 debit from checking account (ACC_001) on 2025-12-18. Category: Shopping > Online Shopping. Transaction ID: TXN_087.
#
#    🔍 Reasoning Steps (6 steps):
#       1. Step 1: Received query requesting last transaction for USER_001 - identified as UC-01 retrieve_single_most_recent_transaction
#       2. Step 2: No pre-resolved parameters needed (no category, date range, or threshold filters required)
#       3. Step 3: Called query_transactions with user_id=USER_001, limit=1, sort_by=date_desc to retrieve most recent transaction
#       4. Step 4: Received 1 transaction from database: TXN_087 dated 2025-12-18
#       5. Step 5: Extracted transaction details: $267.90 debit for Online Shopping on December 18, 2025
#       6. Step 6: Formatted customer-friendly answer with amount, category, and date
#
#    🗄️  Data Sources:
#       • Tables: ['transactions']
#       • Fields: ['transaction_id', 'amount', 'direction', 'date', 'dayOfWeek', 'categoryName', 'subCategoryName', 'account_id', 'account_type']
#       • Filters:
#          - user_id=USER_001
#          - limit=1
#          - sort_by=date_desc
#       • Aggregations: ['None - direct record retrieval']
#
#    📈 Transactions Analyzed: 1
#
#    🎯 Confidence: high
#
# ✅ PASS - Query 2
#
# ====================================================================================================
#
# 📊 TEST SUMMARY
#
# ====================================================================================================
#
# Total: 2
# Passed: 2
# Failed: 0
# Success Rate: 100.0%
#
#    ✅ PASS - Query #1
#    ✅ PASS - Query #2
#
# ====================================================================================================
# [{'id': 1, 'status': '✅ PASS', 'error': None},
#  {'id': 2, 'status': '✅ PASS', 'error': None}]

# %%
# # Silent Mode: VAGUE non-category queries, test 2 queries:
test_vague_queries_no_rag_trn_categories([12, 13], wait_seconds=10)
# Out:
# ====================================================================================================
#
# 🧪 TEST: VAGUE QUERIES WITHOUT RAG TRANSACTION CATEGORIES
#
# ====================================================================================================
#
# Testing 2 queries: [12, 13]
# Wait time: 10 seconds between queries
# Silent mode: ON
#
# 📂 Loading Q&A mapping...
# ✅ Q&A mapping loaded
# 🔧 Building graph...
# ✅ Graph compiled and ready
#
# ====================================================================================================
#
#
# ----------------------------------------------------------------------------------------------------
#
# 📝 QUERY 1/2 (ID: 12)
#
# ----------------------------------------------------------------------------------------------------
#
# 👤 USER: "Show me recent transactions"
#
# 🔹 LLM-1 ROUTER OUTPUT (VAGUE):
#    ✓ Clarity: VAGUE
#    ✓ Core UCs: ['UC-03', 'UC-01']
#    ✓ Primary UC: UC-03
#    ❓ Clarifying Question:
#       "What time period do you mean by 'recent'? For example: last 7 days, last 30 days, or this month?"
#    ❓ Missing Info: ['time_window']
#    ✓ Clarity Reason: Query contains subjective temporal term 'recent' without definition in conversation_summary. This is a user-preference dependent term that requires clarification.
#
# ✅ Correctly identified as VAGUE with clarification
#
#    📋 Missing Info Validation:
#       Expected: ['timeframe']
#       Actual: ['time_window']
#       ⚠️  Missing info mismatch
#
# ✅ PASS - Query 12 (VAGUE detected)
#
# ⏳ Waiting 10 seconds...
#
# ----------------------------------------------------------------------------------------------------
#
# 📝 QUERY 2/2 (ID: 13)
#
# ----------------------------------------------------------------------------------------------------
#
# 👤 USER: "Show me large purchases"
#
# 🔹 LLM-1 ROUTER OUTPUT (VAGUE):
#    ✓ Clarity: VAGUE
#    ✓ Core UCs: ['UC-01', 'UC-05']
#    ✓ Primary UC: UC-05
#    ❓ Clarifying Question:
#       "What amount would you consider a 'large' purchase (e.g., above $50, $100, or $500), and for what time period would you like to see these purchases?"
#    ❓ Missing Info: ['amount_threshold_large', 'time_window']
#    ✓ Clarity Reason: Query contains two subjective terms: 'large' (no threshold defined) and implicit timeframe (not specified). Both require user clarification.
#
# ✅ Correctly identified as VAGUE with clarification
#
#    📋 Missing Info Validation:
#       Expected: ['amount_threshold']
#       Actual: ['amount_threshold_large', 'time_window']
#       ⚠️  Missing info mismatch
#
# ✅ PASS - Query 13 (VAGUE detected)
#
# ====================================================================================================
#
# 📊 TEST SUMMARY
#
# ====================================================================================================
#
# Total: 2
# Passed: 2
# Failed: 0
# Success Rate: 100.0%
#
#    ✅ PASS - Query #12
#    ✅ PASS - Query #13
#
# ====================================================================================================
# [{'id': 12, 'status': '✅ PASS', 'error': None},
#  {'id': 13, 'status': '✅ PASS', 'error': None}]

# %% [markdown]
# ### Verbose mode (see ALL internal logs, including Tool Calling Loop)

# %%
# # Silent Mode: CLEAR non-category queries, test 2 queries:
# test_clear_queries_no_rag_trn_categories([1], silent=False) #, wait_seconds=10)

# # Silent Mode: VAGUE non-category queries, test 2 queries:
# test_vague_queries_no_rag_trn_categories([12, 13],  silent=False, wait_seconds=10)
